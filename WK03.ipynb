# %% [markdown]
# # Week 03: Structured Data
#
# Java Script Object Notation (JSON): another file format to store, transfer and organize data.
#
# ## JSON
#
# - [ansur](https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/json/ansur.json) (6k)
# - [wines](https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/json/wines.json) (8k)
# - [cities](https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/json/cities.json) (9k)
# - [pm2.5](https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/json/pm2_5.json) (41k)
#
# ### Other Sources
# - [Kaggle JSON](https://www.kaggle.com/datasets/?sort=downloadCount&fileType=json)
# - [Hugging Face JSON](https://huggingface.co/datasets?format=format:json&sort=downloads)

# %% [markdown]
# notes:
# ## conditionals ##
#
# == (equals)
# !=(doesn't equal)
#
# ## conjunctions ##
#
# if wine[1] == "US" and float(wine[3]>85)
#
# ## disjunction/union
#
# if wine [1] == "US" or wine[1]=="Spain";
#
# ## combinations
#
# if ((wine[1]=="US" and wine[3]>80)or(wine[1]=="Spain" and wine[4]<100.0))

# %% [markdown]
# ## Setup
#
# Let's run the following $2$ cells to download our datasets and load some helper libraries.

# %%
# !wget -q https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/json/wines.json -P ./data
# !wget -q https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/json/ansur.json -P ./data

# %%
import json

# %% [markdown]
# ## Loading a JSON file
#
# Is similar to loading a `csv` file (and perhaps even easier).
#
# We open the file using the `Python` function `open()`, and then use a library to read the contents of the file, knowing that it's a `json` file.
#
# For `csv` files it was something like this:
#
# ```py
# csvfile = open("./data/wines.csv")
# csvreader = csv.reader(csvfile)
# csvdata = list(csvreader)
# ```
#
# For `json`, it's like this:

# %%
jsonfile = open("./data/wines.json")
data = json.load(jsonfile)

data
# Out:
# [{'ID': 0,
#   'country': 'US',
#   'designation': "Martha's Vineyard",
#   'points': 96,
#   'price': 235.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Heitz'},
#  {'ID': 1,
#   'country': 'Spain',
#   'designation': 'Carodorum Selección Especial Reserva',
#   'points': 96,
#   'price': 110.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Bodega Carmen Rodríguez'},
#  {'ID': 2,
#   'country': 'US',
#   'designation': 'Special Selected Late Harvest',
#   'points': 96,
#   'price': 90.0,
#   'province': 'California',
#   'region': 'Knights Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Macauley'},
#  {'ID': 3,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 96,
#   'price': 65.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ponzi'},
#  {'ID': 4,
#   'country': 'France',
#   'designation': 'La Brûlade',
#   'points': 95,
#   'price': 66.0,
#   'province': 'Provence',
#   'region': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  {'ID': 5,
#   'country': 'Spain',
#   'designation': 'Numanthia',
#   'points': 95,
#   'price': 73.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Numanthia'},
#  {'ID': 6,
#   'country': 'Spain',
#   'designation': 'San Román',
#   'points': 95,
#   'price': 65.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Maurodos'},
#  {'ID': 7,
#   'country': 'Spain',
#   'designation': 'Carodorum Único Crianza',
#   'points': 95,
#   'price': 110.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Bodega Carmen Rodríguez'},
#  {'ID': 8,
#   'country': 'US',
#   'designation': 'Silice',
#   'points': 95,
#   'price': 65.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  {'ID': 9,
#   'country': 'US',
#   'designation': "Gap's Crown Vineyard",
#   'points': 95,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Blue Farm'},
#  {'ID': 10,
#   'country': 'Italy',
#   'designation': 'Ronco della Chiesa',
#   'points': 95,
#   'price': 80.0,
#   'province': 'Northeastern Italy',
#   'region': 'Collio',
#   'variety': 'Friulano',
#   'winery': 'Borgo del Tiglio'},
#  {'ID': 11,
#   'country': 'US',
#   'designation': 'Estate Vineyard Wadensvil Block',
#   'points': 95,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Ribbon Ridge',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  {'ID': 12,
#   'country': 'US',
#   'designation': 'Weber Vineyard',
#   'points': 95,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  {'ID': 13,
#   'country': 'France',
#   'designation': 'Château Montus Prestige',
#   'points': 95,
#   'price': 90.0,
#   'province': 'Southwest France',
#   'region': 'Madiran',
#   'variety': 'Tannat',
#   'winery': 'Vignobles Brumont'},
#  {'ID': 14,
#   'country': 'US',
#   'designation': 'Grace Vineyard',
#   'points': 95,
#   'price': 185.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine Serene'},
#  {'ID': 15,
#   'country': 'US',
#   'designation': 'Sigrid',
#   'points': 95,
#   'price': 90.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Bergström'},
#  {'ID': 16,
#   'country': 'US',
#   'designation': 'Rainin Vineyard',
#   'points': 95,
#   'price': 325.0,
#   'province': 'California',
#   'region': 'Diamond Mountain District',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Hall'},
#  {'ID': 17,
#   'country': 'Spain',
#   'designation': '6 Años Reserva Premium',
#   'points': 95,
#   'price': 80.0,
#   'province': 'Northern Spain',
#   'region': 'Ribera del Duero',
#   'variety': 'Tempranillo',
#   'winery': 'Valduero'},
#  {'ID': 18,
#   'country': 'France',
#   'designation': 'Le Pigeonnier',
#   'points': 95,
#   'price': 290.0,
#   'province': 'Southwest France',
#   'region': 'Cahors',
#   'variety': 'Malbec',
#   'winery': 'Château Lagrézette'},
#  {'ID': 19,
#   'country': 'US',
#   'designation': "Gap's Crown Vineyard",
#   'points': 95,
#   'price': 75.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Gary Farrell'},
#  {'ID': 20,
#   'country': 'US',
#   'designation': 'Grignolino',
#   'points': 95,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Rosé',
#   'winery': 'Heitz'},
#  {'ID': 21,
#   'country': 'Spain',
#   'designation': 'Prado Enea Gran Reserva',
#   'points': 95,
#   'price': 79.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Muga'},
#  {'ID': 22,
#   'country': 'Spain',
#   'designation': 'Termanthia',
#   'points': 95,
#   'price': 220.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Numanthia'},
#  {'ID': 23,
#   'country': 'US',
#   'designation': 'Giallo Solare',
#   'points': 95,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Edna Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Center of Effort'},
#  {'ID': 24,
#   'country': 'US',
#   'designation': 'R-Bar-R Ranch',
#   'points': 95,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Santa Cruz Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Comartin'},
#  {'ID': 26,
#   'country': 'US',
#   'designation': 'Shea Vineyard',
#   'points': 94,
#   'price': 62.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  {'ID': 27,
#   'country': 'US',
#   'designation': 'Abetina',
#   'points': 94,
#   'price': 105.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ponzi'},
#  {'ID': 28,
#   'country': 'US',
#   'designation': "Garys' Vineyard",
#   'points': 94,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Pinot Noir',
#   'winery': 'Roar'},
#  {'ID': 29,
#   'country': 'US',
#   'designation': 'The Funk Estate',
#   'points': 94,
#   'price': 60.0,
#   'province': 'Washington',
#   'region': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Saviah'},
#  {'ID': 31,
#   'country': 'US',
#   'designation': 'Babushka',
#   'points': 90,
#   'price': 37.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Zepaltas'},
#  {'ID': 33,
#   'country': 'France',
#   'designation': 'Nonpareil Trésor Rosé Brut',
#   'points': 90,
#   'price': 22.0,
#   'province': 'France Other',
#   'region': 'Vin Mousseux',
#   'variety': 'Sparkling Blend',
#   'winery': 'Bouvet-Ladubay'},
#  {'ID': 34,
#   'country': 'US',
#   'designation': 'Conner Lee Vineyard',
#   'points': 90,
#   'price': 42.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Chardonnay',
#   'winery': 'Buty'},
#  {'ID': 35,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 135.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Carillon'},
#  {'ID': 39,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 29.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Castello di Monterinaldi'},
#  {'ID': 40,
#   'country': 'Spain',
#   'designation': 'Amandi',
#   'points': 90,
#   'price': 17.0,
#   'province': 'Galicia',
#   'region': 'Ribeira Sacra',
#   'variety': 'Mencía',
#   'winery': 'Don Bernardino'},
#  {'ID': 41,
#   'country': 'Spain',
#   'designation': 'Alfonso Oloroso Seco',
#   'points': 90,
#   'price': 26.0,
#   'province': 'Andalucia',
#   'region': 'Jerez',
#   'variety': 'Palomino',
#   'winery': 'González Byass'},
#  {'ID': 43,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 39.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Rignana'},
#  {'ID': 44,
#   'country': 'France',
#   'designation': 'Coteaux',
#   'points': 90,
#   'price': 69.0,
#   'province': 'Rhône Valley',
#   'region': 'Cornas',
#   'variety': 'Syrah',
#   'winery': 'Tardieu-Laurent'},
#  {'ID': 45,
#   'country': 'Italy',
#   'designation': 'Vigneto Odoardo Beccari Riserva',
#   'points': 90,
#   'price': 30.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Vignavecchia'},
#  {'ID': 46,
#   'country': 'Italy',
#   'designation': 'Poggio alle Mura',
#   'points': 90,
#   'price': 90.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Banfi'},
#  {'ID': 47,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 90,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Brandlin'},
#  {'ID': 50,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 100.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Capanne Ricci'},
#  {'ID': 52,
#   'country': 'France',
#   'designation': 'Les 7 Hommes',
#   'points': 90,
#   'price': 42.0,
#   'province': 'Loire Valley',
#   'region': 'Sancerre',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Cherrier Frères'},
#  {'ID': 53,
#   'country': 'France',
#   'designation': "L'Inédit",
#   'points': 90,
#   'price': 28.0,
#   'province': 'Loire Valley',
#   'region': 'Coteaux du Giennois',
#   'variety': 'Pinot Noir',
#   'winery': 'Clement et Florian Berthier'},
#  {'ID': 55,
#   'country': 'US',
#   'designation': 'Four Flags',
#   'points': 90,
#   'price': 69.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'DeLille'},
#  {'ID': 57,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 90,
#   'price': 25.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Dr. Konstantin Frank'},
#  {'ID': 58,
#   'country': 'US',
#   'designation': 'Final Final',
#   'points': 90,
#   'price': 30.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Cabernet Sauvignon-Syrah',
#   'winery': 'Efeste'},
#  {'ID': 59,
#   'country': 'Italy',
#   'designation': 'Poggio Bestiale',
#   'points': 90,
#   'price': 60.0,
#   'province': 'Tuscany',
#   'region': 'Maremma Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Fattoria di Magliano'},
#  {'ID': 60,
#   'country': 'Argentina',
#   'designation': "The Apple Doesn't Fall Far From The Tree",
#   'points': 91,
#   'price': 30.0,
#   'province': 'Mendoza Province',
#   'region': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Matias Riccitelli'},
#  {'ID': 62,
#   'country': 'Argentina',
#   'designation': 'Alegoría Gran Reserva',
#   'points': 91,
#   'price': 25.0,
#   'province': 'Mendoza Province',
#   'region': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Navarro Correas'},
#  {'ID': 63,
#   'country': 'France',
#   'designation': "L'Homme Mort Premier Cru",
#   'points': 91,
#   'price': 45.0,
#   'province': 'Burgundy',
#   'region': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Chenevières'},
#  {'ID': 65,
#   'country': 'US',
#   'designation': 'Estate Select',
#   'points': 91,
#   'price': 36.0,
#   'province': 'California',
#   'region': 'Santa Clara Valley',
#   'variety': 'Syrah',
#   'winery': 'Jason-Stephens'},
#  {'ID': 66,
#   'country': 'France',
#   'designation': 'Fourchaume Premier Cru',
#   'points': 91,
#   'price': 38.0,
#   'province': 'Burgundy',
#   'region': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Louis Max'},
#  {'ID': 67,
#   'country': 'US',
#   'designation': 'Animo',
#   'points': 91,
#   'price': 85.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Michael Mondavi Family Estate'},
#  {'ID': 68,
#   'country': 'US',
#   'designation': 'Schindler Vineyard',
#   'points': 91,
#   'price': 50.0,
#   'province': 'Oregon',
#   'region': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Panther Creek'},
#  {'ID': 69,
#   'country': 'US',
#   'designation': 'Barrel Select',
#   'points': 91,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Rutherford',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Provenance Vineyards'},
#  {'ID': 70,
#   'country': 'US',
#   'designation': 'District Collection',
#   'points': 91,
#   'price': 85.0,
#   'province': 'California',
#   'region': 'St. Helena',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Raymond'},
#  {'ID': 75,
#   'country': 'US',
#   'designation': 'Premier Cuvée',
#   'points': 91,
#   'price': 54.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Archery Summit'},
#  {'ID': 76,
#   'country': 'France',
#   'designation': "Le Nombre d'Or Brut Nature",
#   'points': 91,
#   'price': 85.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Chardonnay',
#   'winery': 'Aubry'},
#  {'ID': 77,
#   'country': 'US',
#   'designation': 'Juliana Vineyard',
#   'points': 91,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'B Cellars'},
#  {'ID': 79,
#   'country': 'Italy',
#   'designation': 'Boscato',
#   'points': 91,
#   'price': 75.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Bel Colle'},
#  {'ID': 80,
#   'country': 'US',
#   'designation': 'Aeolian',
#   'points': 91,
#   'price': 42.0,
#   'province': 'Oregon',
#   'region': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Bethel Heights'},
#  {'ID': 83,
#   'country': 'Italy',
#   'designation': "del Comune di Serralunga d'Alba",
#   'points': 91,
#   'price': 59.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina Cucco'},
#  {'ID': 84,
#   'country': 'Italy',
#   'designation': 'Bricco Luciani',
#   'points': 91,
#   'price': 85.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina del Monastero'},
#  {'ID': 85,
#   'country': 'Italy',
#   'designation': 'Bricco Gattera',
#   'points': 91,
#   'price': 80.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cordero di Montezemolo'},
#  {'ID': 86,
#   'country': 'France',
#   'designation': 'Montmains Premier Cru',
#   'points': 91,
#   'price': 45.0,
#   'province': 'Burgundy',
#   'region': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Gérard Duplessis'},
#  {'ID': 88,
#   'country': 'US',
#   'designation': 'Bacigalupi Vineyard',
#   'points': 91,
#   'price': 65.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Eleven Eleven'},
#  {'ID': 89,
#   'country': 'US',
#   'designation': 'Magnificat',
#   'points': 91,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Meritage',
#   'winery': 'Franciscan'},
#  {'ID': 92,
#   'country': 'Italy',
#   'designation': 'Nature',
#   'points': 86,
#   'price': 22.0,
#   'province': 'Veneto',
#   'region': 'Prosecco',
#   'variety': 'Glera',
#   'winery': 'De Stefani'},
#  {'ID': 93,
#   'country': 'US',
#   'designation': 'Small Lot Blend',
#   'points': 86,
#   'price': 13.0,
#   'province': 'California',
#   'region': 'Mendocino County',
#   'variety': 'Chardonnay',
#   'winery': 'Parducci'},
#  {'ID': 95,
#   'country': 'France',
#   'designation': 'Château Beauvillain-Monpezat',
#   'points': 86,
#   'price': 14.0,
#   'province': 'Southwest France',
#   'region': 'Cahors',
#   'variety': 'Malbec-Merlot',
#   'winery': 'Rigal'},
#  {'ID': 98,
#   'country': 'France',
#   'designation': 'Pigmentum',
#   'points': 86,
#   'price': 15.0,
#   'province': 'Southwest France',
#   'region': 'Buzet',
#   'variety': 'Merlot-Malbec',
#   'winery': 'Georges Vigouroux'},
#  {'ID': 99,
#   'country': 'France',
#   'designation': 'Pigmentum',
#   'points': 86,
#   'price': 10.0,
#   'province': 'Southwest France',
#   'region': 'Côtes de Gascogne',
#   'variety': 'Ugni Blanc-Colombard',
#   'winery': 'Georges Vigouroux'},
#  {'ID': 101,
#   'country': 'US',
#   'designation': 'Stephanie',
#   'points': 86,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Hestan'},
#  {'ID': 103,
#   'country': 'US',
#   'designation': "Bella's Blend",
#   'points': 86,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Knights Valley',
#   'variety': 'Cabernet Sauvignon-Cabernet Franc',
#   'winery': 'Ehret'},
#  {'ID': 104,
#   'country': 'US',
#   'designation': 'Tears of Dew Late Harvest',
#   'points': 86,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Moscato',
#   'winery': 'EOS'},
#  {'ID': 105,
#   'country': 'US',
#   'designation': 'Tudor Hills Vineyard',
#   'points': 86,
#   'price': 17.0,
#   'province': 'Washington',
#   'region': 'Yakima Valley',
#   'variety': 'Pinot Grigio',
#   'winery': 'Martinez & Martinez'},
#  {'ID': 109,
#   'country': 'US',
#   'designation': 'Homestead Block',
#   'points': 86,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Kuleto Estate'},
#  {'ID': 111,
#   'country': 'Argentina',
#   'designation': 'Terroir Único Pinot Noir',
#   'points': 86,
#   'price': 12.0,
#   'province': 'Mendoza Province',
#   'region': 'Tupungato',
#   'variety': 'Rosé',
#   'winery': 'Zorzal'},
#  {'ID': 112,
#   'country': 'US',
#   'designation': 'Limited Release Cold Springs Vineyard',
#   'points': 86,
#   'price': 125.0,
#   'province': 'California',
#   'region': 'Howell Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Charles Krug'},
#  {'ID': 113,
#   'country': 'US',
#   'designation': 'Castle Hill Vineyard',
#   'points': 86,
#   'price': 25.0,
#   'province': 'New York',
#   'region': 'Hudson River Region',
#   'variety': 'Riesling',
#   'winery': 'Millbrook'},
#  {'ID': 115,
#   'country': 'Argentina',
#   'designation': 'Reserva',
#   'points': 86,
#   'price': 15.0,
#   'province': 'Mendoza Province',
#   'region': 'Valle de Uco',
#   'variety': 'Malbec',
#   'winery': 'Viñalba'},
#  {'ID': 120,
#   'country': 'US',
#   'designation': 'The Flyer',
#   'points': 91,
#   'price': 59.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'MacPhail'},
#  {'ID': 121,
#   'country': 'US',
#   'designation': 'Charles Vineyard Clone 05',
#   'points': 91,
#   'price': 49.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Foursight'},
#  {'ID': 122,
#   'country': 'US',
#   'designation': 'Solomon Hills Vineyard Rosé',
#   'points': 91,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Santa Maria Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Goat Bubbles'},
#  {'ID': 123,
#   'country': 'US',
#   'designation': 'Paris Tasting Commemorative',
#   'points': 91,
#   'price': 93.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Grgich Hills'},
#  {'ID': 124,
#   'country': 'US',
#   'designation': "Methode a l'Ancienne",
#   'points': 91,
#   'price': 32.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Navarro'},
#  {'ID': 126,
#   'country': 'US',
#   'designation': 'Grand Wren',
#   'points': 90,
#   'price': 100.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Zinfandel',
#   'winery': 'Renwood'},
#  {'ID': 127,
#   'country': 'US',
#   'designation': 'Central Park West Vineyard',
#   'points': 90,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'St. Helena',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Trinchero'},
#  {'ID': 128,
#   'country': 'Spain',
#   'designation': 'Arnegui Reserva',
#   'points': 90,
#   'price': 22.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Pagos del Rey'},
#  {'ID': 129,
#   'country': 'Italy',
#   'designation': 'Chianta Bianco',
#   'points': 90,
#   'price': 45.0,
#   'province': 'Sicily & Sardinia',
#   'region': 'Etna',
#   'variety': 'White Blend',
#   'winery': 'Biondi'},
#  {'ID': 132,
#   'country': 'US',
#   'designation': 'Cooper Ranch',
#   'points': 90,
#   'price': 26.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Barbera',
#   'winery': 'Andis'},
#  {'ID': 134,
#   'country': 'US',
#   'designation': 'Longwood',
#   'points': 90,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Beaucanon'},
#  {'ID': 135,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 90,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Adelaida District',
#   'variety': 'Grenache',
#   'winery': 'Brecon Estate'},
#  {'ID': 136,
#   'country': 'US',
#   'designation': 'Mustang Springs',
#   'points': 90,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Adelaida District',
#   'variety': 'Zinfandel',
#   'winery': 'Peachy Canyon'},
#  {'ID': 137,
#   'country': 'US',
#   'designation': 'SMC',
#   'points': 90,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'California',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Three'},
#  {'ID': 138,
#   'country': 'Spain',
#   'designation': 'Crianza',
#   'points': 90,
#   'price': 17.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Valdelacierva'},
#  {'ID': 139,
#   'country': 'France',
#   'designation': 'Le',
#   'points': 90,
#   'price': 18.0,
#   'province': 'Languedoc-Roussillon',
#   'region': 'Coteaux du Languedoc Pic Saint Loup',
#   'variety': 'Rosé',
#   'winery': 'Château de Lancyre'},
#  {'ID': 141,
#   'country': 'US',
#   'designation': 'Rte Blanc',
#   'points': 90,
#   'price': 28.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Clif Family'},
#  {'ID': 142,
#   'country': 'US',
#   'designation': 'Hook Vineyard',
#   'points': 90,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Grenache',
#   'winery': 'Santa Cruz Mountain Vineyard'},
#  {'ID': 144,
#   'country': 'US',
#   'designation': 'Jespersen Ranch',
#   'points': 90,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Edna Valley',
#   'variety': 'Albariño',
#   'winery': 'Stephen Ross'},
#  {'ID': 146,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 90,
#   'price': 36.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Grgich Hills'},
#  {'ID': 152,
#   'country': 'Spain',
#   'designation': 'Brut Reserva',
#   'points': 89,
#   'price': 17.0,
#   'province': 'Catalonia',
#   'region': 'Cava',
#   'variety': 'Sparkling Blend',
#   'winery': 'Bohigas'},
#  {'ID': 158,
#   'country': 'Spain',
#   'designation': 'Viña Real Gran Reserva',
#   'points': 89,
#   'price': 44.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'CVNE'},
#  {'ID': 160,
#   'country': 'US',
#   'designation': 'Range 30 West',
#   'points': 89,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Happy Canyon of Santa Barbara',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Foxen 7200'},
#  {'ID': 162,
#   'country': 'Spain',
#   'designation': 'Gaudium',
#   'points': 89,
#   'price': 44.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Marqués de Cáceres'},
#  {'ID': 164,
#   'country': 'US',
#   'designation': 'Mill Road Vineyard',
#   'points': 89,
#   'price': 23.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Viognier',
#   'winery': 'Eberle'},
#  {'ID': 165,
#   'country': 'US',
#   'designation': 'Freedom Hill Vineyard',
#   'points': 89,
#   'price': 36.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Silvan Ridge'},
#  {'ID': 166,
#   'country': 'Italy',
#   'designation': 'Le Redini',
#   'points': 89,
#   'price': 25.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Tenuta degli Dei'},
#  {'ID': 167,
#   'country': 'Italy',
#   'designation': 'Il Guardiano',
#   'points': 89,
#   'price': 22.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Poggio Mandorlo'},
#  {'ID': 169,
#   'country': 'US',
#   'designation': 'Del Arroyo Vineyard',
#   'points': 89,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Livermore Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Occasio'},
#  {'ID': 173,
#   'country': 'US',
#   'designation': 'Charles Vineyard Clone O5',
#   'points': 89,
#   'price': 49.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Foursight'},
#  {'ID': 174,
#   'country': 'France',
#   'designation': 'Héritages Elevé en Foudres de Chêne',
#   'points': 89,
#   'price': 16.0,
#   'province': 'Rhône Valley',
#   'region': 'Côtes du Rhône',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Ogier'},
#  {'ID': 175,
#   'country': 'Spain',
#   'designation': 'Gran Bajoz',
#   'points': 89,
#   'price': 30.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Pagos del Rey'},
#  {'ID': 176,
#   'country': 'Italy',
#   'designation': 'Palazzo Altesi',
#   'points': 89,
#   'price': 40.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Sangiovese',
#   'winery': 'Altesino'},
#  {'ID': 177,
#   'country': 'Italy',
#   'designation': 'Il Borgo',
#   'points': 89,
#   'price': 57.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Cabreo'},
#  {'ID': 178,
#   'country': 'US',
#   'designation': 'Lot 525',
#   'points': 89,
#   'price': 29.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Cameron Hughes'},
#  {'ID': 181,
#   'country': 'US',
#   'designation': 'Estate Reserve',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Syrah',
#   'winery': 'San Simeon'},
#  {'ID': 182,
#   'country': 'US',
#   'designation': 'Sonatera Vineyard',
#   'points': 88,
#   'price': 49.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Siduri'},
#  {'ID': 183,
#   'country': 'US',
#   'designation': 'Boushey Vineyard',
#   'points': 88,
#   'price': 20.0,
#   'province': 'Washington',
#   'region': 'Yakima Valley',
#   'variety': 'Picpoul',
#   'winery': 'Syncline'},
#  {'ID': 184,
#   'country': 'Argentina',
#   'designation': 'Trinità Grand Reserve',
#   'points': 88,
#   'price': 26.0,
#   'province': 'Mendoza Province',
#   'region': 'Luján de Cuyo',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Piattelli'},
#  {'ID': 185,
#   'country': 'US',
#   'designation': 'Entwined',
#   'points': 88,
#   'price': 34.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Pondera'},
#  {'ID': 186,
#   'country': 'US',
#   'designation': 'French Camp Vineyard',
#   'points': 88,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Tobin James'},
#  {'ID': 187,
#   'country': 'US',
#   'designation': 'French Camp Vineyard',
#   'points': 88,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Tobin James'},
#  {'ID': 188,
#   'country': 'Spain',
#   'designation': 'Sobre Lías',
#   'points': 88,
#   'price': 25.0,
#   'province': 'Northern Spain',
#   'region': 'Valdeorras',
#   'variety': 'Godello',
#   'winery': 'Valdesil'},
#  {'ID': 189,
#   'country': 'Spain',
#   'designation': 'Negre',
#   'points': 87,
#   'price': 22.0,
#   'province': 'Catalonia',
#   'region': 'Montsant',
#   'variety': 'Red Blend',
#   'winery': 'Jaspi'},
#  {'ID': 190,
#   'country': 'Argentina',
#   'designation': 'Reserve',
#   'points': 87,
#   'price': 15.0,
#   'province': 'Mendoza Province',
#   'region': 'Tupungato',
#   'variety': 'Malbec',
#   'winery': 'Tupun'},
#  {'ID': 197,
#   'country': 'US',
#   'designation': 'Rosé of',
#   'points': 87,
#   'price': 18.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Malbec',
#   'winery': 'Hamilton'},
#  {'ID': 198,
#   'country': 'US',
#   'designation': 'Ingle Vineyard Unoaked',
#   'points': 87,
#   'price': 18.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Chardonnay',
#   'winery': 'Heron Hill'},
#  {'ID': 199,
#   'country': 'US',
#   'designation': 'Semi-Dry',
#   'points': 87,
#   'price': 14.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Heron Hill'},
#  {'ID': 200,
#   'country': 'US',
#   'designation': 'Semi-Dry',
#   'points': 87,
#   'price': 14.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Fox Run'},
#  {'ID': 201,
#   'country': 'US',
#   'designation': 'Ice Wine',
#   'points': 87,
#   'price': 40.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Cabernet Franc',
#   'winery': 'Glenora'},
#  {'ID': 208,
#   'country': 'US',
#   'designation': 'Weinbau',
#   'points': 87,
#   'price': 32.0,
#   'province': 'Washington',
#   'region': 'Wahluke Slope',
#   'variety': 'Grenache',
#   'winery': 'Sol Stone'},
#  {'ID': 209,
#   'country': 'Spain',
#   'designation': 'Yá Cuvée 23 Brut Rosé',
#   'points': 87,
#   'price': 18.0,
#   'province': 'Catalonia',
#   'region': 'Cava',
#   'variety': 'Sparkling Blend',
#   'winery': 'Sumarroca'},
#  {'ID': 211,
#   'country': 'Italy',
#   'designation': 'Nervo',
#   'points': 93,
#   'price': 49.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Rizzi'},
#  {'ID': 212,
#   'country': 'US',
#   'designation': 'Rocky Ridge Vineyard',
#   'points': 93,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Rockpile',
#   'variety': 'Zinfandel',
#   'winery': 'Robert Biale'},
#  {'ID': 213,
#   'country': 'Italy',
#   'designation': 'Fausoni',
#   'points': 93,
#   'price': 58.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Sottimano'},
#  {'ID': 214,
#   'country': 'France',
#   'designation': 'Rosacker Grand Cru',
#   'points': 93,
#   'price': 39.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Jean-Luc Mader'},
#  {'ID': 215,
#   'country': 'France',
#   'designation': 'Clos Häuserer Wintzenheim',
#   'points': 93,
#   'price': 65.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Zind-Humbrecht'},
#  {'ID': 218,
#   'country': 'France',
#   'designation': 'Pfingstberg Paradis Grand Cru',
#   'points': 93,
#   'price': 42.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine François Schmitt'},
#  {'ID': 219,
#   'country': 'France',
#   'designation': 'Altenberg de Bergheim Grand Cru Vieilles Vignes',
#   'points': 93,
#   'price': 61.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Gustave Lorentz'},
#  {'ID': 220,
#   'country': 'US',
#   'designation': 'Collaboration Series VI Ciel du Cheval Vineyard',
#   'points': 93,
#   'price': 58.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'G-S-M',
#   'winery': 'Force Majeure'},
#  {'ID': 221,
#   'country': 'US',
#   'designation': 'Hastings Ranch Vineyard',
#   'points': 93,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Mourvèdre',
#   'winery': 'Anglim'},
#  {'ID': 222,
#   'country': 'France',
#   'designation': 'Heissenberg',
#   'points': 93,
#   'price': 48.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Ostertag'},
#  {'ID': 223,
#   'country': 'US',
#   'designation': 'Stagecoach Vineyards The Biale Block',
#   'points': 93,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Robert Biale'},
#  {'ID': 224,
#   'country': 'Italy',
#   'designation': 'Pajorè',
#   'points': 93,
#   'price': 58.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Sottimano'},
#  {'ID': 226,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 93,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Fort Ross-Seaview',
#   'variety': 'Syrah',
#   'winery': 'Red Car'},
#  {'ID': 227,
#   'country': 'US',
#   'designation': 'Collaboration Series V Ciel du Cheval Vineyard',
#   'points': 93,
#   'price': 80.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Force Majeure'},
#  {'ID': 228,
#   'country': 'US',
#   'designation': 'White Hawk Vineyard',
#   'points': 93,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Santa Barbara County',
#   'variety': 'Syrah',
#   'winery': 'Mulvane Wine Co.'},
#  {'ID': 230,
#   'country': 'US',
#   'designation': 'Double Canyon Vineyard',
#   'points': 93,
#   'price': 48.0,
#   'province': 'Washington',
#   'region': 'Horse Heaven Hills',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Double Canyon'},
#  {'ID': 231,
#   'country': 'US',
#   'designation': 'Red Rock Terrace',
#   'points': 93,
#   'price': 200.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Diamond Creek'},
#  {'ID': 232,
#   'country': 'US',
#   'designation': 'Ciel du Cheval Vineyard',
#   'points': 93,
#   'price': 39.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Petit Verdot',
#   'winery': 'Côtes de Ciel'},
#  {'ID': 233,
#   'country': 'US',
#   'designation': 'Kingpin',
#   'points': 93,
#   'price': 62.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Sparkman'},
#  {'ID': 235,
#   'country': 'France',
#   'designation': 'Domaine Saint-Rémy Schlosberg Grand Cru',
#   'points': 92,
#   'price': 35.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Ehrhart'},
#  {'ID': 236,
#   'country': 'France',
#   'designation': 'Pfersigberg Grand Cru',
#   'points': 92,
#   'price': 48.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Zinck'},
#  {'ID': 237,
#   'country': 'France',
#   'designation': 'Calcaire',
#   'points': 92,
#   'price': 55.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Zind-Humbrecht'},
#  {'ID': 239,
#   'country': 'Italy',
#   'designation': 'Coste Rubin',
#   'points': 92,
#   'price': 69.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Fontanafredda'},
#  {'ID': 246,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 88,
#   'price': 36.0,
#   'province': 'Oregon',
#   'region': 'McMinnville',
#   'variety': 'Pinot Noir',
#   'winery': 'Coeur de Terre'},
#  {'ID': 248,
#   'country': 'US',
#   'designation': 'Limited Selection',
#   'points': 88,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Central Coast',
#   'variety': 'Chardonnay',
#   'winery': 'Daniel Gehrs'},
#  {'ID': 249,
#   'country': 'US',
#   'designation': "Cuvée Luke Saralee's Vineyard",
#   'points': 88,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Rhône-style White Blend',
#   'winery': 'Davis Family'},
#  {'ID': 252,
#   'country': 'US',
#   'designation': "Wits' End",
#   'points': 88,
#   'price': 60.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Roco'},
#  {'ID': 253,
#   'country': 'US',
#   'designation': 'Toyon Farm',
#   'points': 88,
#   'price': 54.0,
#   'province': 'California',
#   'region': 'Carneros',
#   'variety': 'Pinot Noir',
#   'winery': 'Saintsbury'},
#  {'ID': 254,
#   'country': 'US',
#   'designation': 'Early',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Muscat',
#   'winery': 'Silvan Ridge'},
#  {'ID': 255,
#   'country': 'Italy',
#   'designation': 'Bussia',
#   'points': 88,
#   'price': 56.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Silvano Bolmida'},
#  {'ID': 256,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 88,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'St. Supéry'},
#  {'ID': 257,
#   'country': 'US',
#   'designation': 'Guidotti Vineyard',
#   'points': 88,
#   'price': 61.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Pinot Noir',
#   'winery': 'Testarossa'},
#  {'ID': 259,
#   'country': 'Spain',
#   'designation': 'Prestigio',
#   'points': 88,
#   'price': 30.0,
#   'province': 'Northern Spain',
#   'region': 'Cigales',
#   'variety': 'Tempranillo',
#   'winery': 'Val de Los Frailes'},
#  {'ID': 260,
#   'country': 'Spain',
#   'designation': 'Crianza',
#   'points': 88,
#   'price': 17.0,
#   'province': 'Central Spain',
#   'region': 'La Mancha',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Yuntero'},
#  {'ID': 262,
#   'country': 'US',
#   'designation': 'Querida',
#   'points': 88,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Cabernet Sauvignon-Merlot',
#   'winery': 'Oso Libre'},
#  {'ID': 263,
#   'country': 'US',
#   'designation': 'Primoroso',
#   'points': 88,
#   'price': 39.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Red Blend',
#   'winery': 'Oso Libre'},
#  {'ID': 264,
#   'country': 'Italy',
#   'designation': "del Comune di Serralunga d'Alba",
#   'points': 88,
#   'price': 49.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Palladino'},
#  {'ID': 265,
#   'country': 'France',
#   'designation': 'Domaine de Saint-Pierre',
#   'points': 88,
#   'price': 23.0,
#   'province': 'Loire Valley',
#   'region': 'Sancerre',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Pierre Prieur et Fils'},
#  {'ID': 267,
#   'country': 'US',
#   'designation': "Anna's Estate Vineyard",
#   'points': 88,
#   'price': 32.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Mourvèdre',
#   'winery': 'Adelaida'},
#  {'ID': 269,
#   'country': 'Argentina',
#   'designation': 'Single Vineyard Reserva',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Mendoza Province',
#   'region': 'Agrelo',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Lamadrid'},
#  {'ID': 270,
#   'country': 'France',
#   'designation': 'Pertuisots Premier Cru',
#   'points': 92,
#   'price': 92.0,
#   'province': 'Burgundy',
#   'region': 'Beaune',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine de Bellene'},
#  {'ID': 271,
#   'country': 'France',
#   'designation': 'Clos du Cailleret Premier Cru',
#   'points': 92,
#   'price': 94.0,
#   'province': 'Burgundy',
#   'region': 'Chassagne-Montrachet',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Vincent Girardin'},
#  {'ID': 272,
#   'country': 'US',
#   'designation': 'Haynes Vineyard',
#   'points': 92,
#   'price': 58.0,
#   'province': 'California',
#   'region': 'Coombsville',
#   'variety': 'Chardonnay',
#   'winery': 'Failla'},
#  {'ID': 273,
#   'country': 'US',
#   'designation': 'Suzuri Series Shake Ridge Ranch',
#   'points': 92,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Gallica'},
#  {'ID': 274,
#   'country': 'US',
#   'designation': 'Vintage Brut',
#   'points': 92,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'J Vineyards & Winery'},
#  {'ID': 276,
#   'country': 'Italy',
#   'designation': 'Sirmian',
#   'points': 92,
#   'price': 27.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Pinot Bianco',
#   'winery': 'Nals Margreid'},
#  {'ID': 279,
#   'country': 'US',
#   'designation': 'Solomon Hills Vineyard',
#   'points': 92,
#   'price': 43.0,
#   'province': 'California',
#   'region': 'Santa Maria Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ryan Cochrane'},
#  {'ID': 280,
#   'country': 'Italy',
#   'designation': 'Monte Carbonare',
#   'points': 92,
#   'price': 33.0,
#   'province': 'Veneto',
#   'region': 'Soave Classico',
#   'variety': 'Garganega',
#   'winery': 'Suavia'},
#  {'ID': 281,
#   'country': 'Italy',
#   'designation': 'Quarz',
#   'points': 92,
#   'price': 60.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Sauvignon',
#   'winery': 'Cantina Terlano'},
#  {'ID': 283,
#   'country': 'France',
#   'designation': 'Réserve',
#   'points': 92,
#   'price': 30.0,
#   'province': 'Bordeaux',
#   'region': 'Graves',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Haut Selve'},
#  {'ID': 284,
#   'country': 'US',
#   'designation': 'Lampyridae Vineyards',
#   'points': 92,
#   'price': 100.0,
#   'province': 'California',
#   'region': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Communication Block'},
#  {'ID': 285,
#   'country': 'US',
#   'designation': 'Le Mistral Vineyard',
#   'points': 92,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Monterey County',
#   'variety': 'Syrah',
#   'winery': 'Baker & Brain'},
#  {'ID': 286,
#   'country': 'France',
#   'designation': 'Les Charmes Dessus',
#   'points': 91,
#   'price': 60.0,
#   'province': 'Burgundy',
#   'region': 'Santenay',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine de Bellene'},
#  {'ID': 287,
#   'country': 'France',
#   'designation': 'Cuvée Germain',
#   'points': 91,
#   'price': 16.0,
#   'province': 'Southwest France',
#   'region': 'Côtes du Tarn',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': "Domaine D'en Ségur"},
#  {'ID': 288,
#   'country': 'France',
#   'designation': 'Quintessence',
#   'points': 91,
#   'price': 40.0,
#   'province': 'Burgundy',
#   'region': 'Pouilly-Fuissé',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Sangouard-Guyot'},
#  {'ID': 289,
#   'country': 'US',
#   'designation': 'Clay Court',
#   'points': 91,
#   'price': 60.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Elk Cove'},
#  {'ID': 293,
#   'country': 'US',
#   'designation': 'Kruse Vineyards',
#   'points': 91,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Syrah',
#   'winery': 'Jack Creek'},
#  {'ID': 295,
#   'country': 'US',
#   'designation': 'Rosé of',
#   'points': 91,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Brick & Mortar'},
#  {'ID': 296,
#   'country': 'Italy',
#   'designation': 'Prail',
#   'points': 91,
#   'price': 25.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Sauvignon',
#   'winery': 'Colterenzio'},
#  {'ID': 297,
#   'country': 'Italy',
#   'designation': 'Puiten',
#   'points': 91,
#   'price': 23.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Pinot Grigio',
#   'winery': 'Colterenzio'},
#  {'ID': 298,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 91,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Carneros',
#   'variety': 'Pinot Noir',
#   'winery': 'Cuvaison'},
#  {'ID': 299,
#   'country': 'US',
#   'designation': 'Nova Vineyard',
#   'points': 91,
#   'price': 32.0,
#   'province': 'California',
#   'region': 'Clear Lake',
#   'variety': 'Zinfandel',
#   'winery': 'De Loach'},
#  {'ID': 300,
#   'country': 'US',
#   'designation': 'The Funk Estate',
#   'points': 94,
#   'price': 60.0,
#   'province': 'Washington',
#   'region': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Saviah'},
#  {'ID': 301,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 94,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Riesling',
#   'winery': 'Smith-Madrone'},
#  {'ID': 302,
#   'country': 'Italy',
#   'designation': "Vigneto Monte Sant'Urbano",
#   'points': 94,
#   'price': 85.0,
#   'province': 'Veneto',
#   'region': 'Amarone della Valpolicella Classico',
#   'variety': 'Red Blend',
#   'winery': 'Speri'},
#  {'ID': 303,
#   'country': 'US',
#   'designation': 'White',
#   'points': 94,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Riesling',
#   'winery': 'Stony Hill'},
#  {'ID': 304,
#   'country': 'US',
#   'designation': 'Sierra Madre Vineyard',
#   'points': 94,
#   'price': 65.0,
#   'province': 'California',
#   'region': 'Santa Maria Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Testarossa'},
#  {'ID': 306,
#   'country': 'US',
#   'designation': 'Bergström Vineyard',
#   'points': 94,
#   'price': 90.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  {'ID': 307,
#   'country': 'US',
#   'designation': 'Angel Hawk',
#   'points': 94,
#   'price': 85.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Black Kite'},
#  {'ID': 308,
#   'country': 'US',
#   'designation': 'King Ridge Vineyard Hirsch Selection',
#   'points': 94,
#   'price': 70.0,
#   'province': 'California',
#   'region': 'Fort Ross-Seaview',
#   'variety': 'Pinot Noir',
#   'winery': 'Blue Farm'},
#  {'ID': 309,
#   'country': 'US',
#   'designation': 'Evenstad Reserve',
#   'points': 94,
#   'price': 70.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine Serene'},
#  {'ID': 310,
#   'country': 'US',
#   'designation': 'Bacigalupi Vineyard',
#   'points': 94,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Gary Farrell'},
#  {'ID': 311,
#   'country': 'Italy',
#   'designation': 'Contrada Salvarenza Vecchie Vigne',
#   'points': 94,
#   'price': 38.0,
#   'province': 'Veneto',
#   'region': 'Soave Classico',
#   'variety': 'Garganega',
#   'winery': 'Gini'},
#  {'ID': 312,
#   'country': 'Italy',
#   'designation': 'La Froscà',
#   'points': 94,
#   'price': 29.0,
#   'province': 'Veneto',
#   'region': 'Soave Classico',
#   'variety': 'Garganega',
#   'winery': 'Gini'},
#  {'ID': 313,
#   'country': 'US',
#   'designation': 'Outer Limits',
#   'points': 94,
#   'price': 155.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Parallel'},
#  {'ID': 314,
#   'country': 'US',
#   'designation': 'Durant Vineyard Bishop Block',
#   'points': 94,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  {'ID': 315,
#   'country': 'US',
#   'designation': 'Godspeed',
#   'points': 94,
#   'price': 95.0,
#   'province': 'California',
#   'region': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Sbragia'},
#  {'ID': 316,
#   'country': 'US',
#   'designation': 'Tognetti Vineyard Brut',
#   'points': 94,
#   'price': 80.0,
#   'province': 'California',
#   'region': 'Carneros',
#   'variety': 'Sparkling Blend',
#   'winery': 'Schramsberg'},
#  {'ID': 317,
#   'country': 'US',
#   'designation': 'Ribbon Ridge Estate',
#   'points': 94,
#   'price': 49.0,
#   'province': 'Oregon',
#   'region': 'Ribbon Ridge',
#   'variety': 'Pinot Noir',
#   'winery': 'Trisaetum'},
#  {'ID': 318,
#   'country': 'France',
#   'designation': 'Château Montus',
#   'points': 94,
#   'price': 35.0,
#   'province': 'Southwest France',
#   'region': 'Madiran',
#   'variety': 'Tannat-Cabernet',
#   'winery': 'Vignobles Brumont'},
#  {'ID': 319,
#   'country': 'US',
#   'designation': 'Old Stones',
#   'points': 94,
#   'price': 50.0,
#   'province': 'Washington',
#   'region': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Waters'},
#  {'ID': 320,
#   'country': 'France',
#   'designation': 'La Bégude',
#   'points': 94,
#   'price': 44.0,
#   'province': 'Provence',
#   'region': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  {'ID': 321,
#   'country': 'Spain',
#   'designation': 'QP',
#   'points': 94,
#   'price': 68.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Bodega Classica'},
#  {'ID': 324,
#   'country': 'US',
#   'designation': 'Pellet Vineyard',
#   'points': 94,
#   'price': 95.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Pellet Estate'},
#  {'ID': 325,
#   'country': 'France',
#   'designation': 'La Bégude',
#   'points': 94,
#   'price': 44.0,
#   'province': 'Provence',
#   'region': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  {'ID': 326,
#   'country': 'Argentina',
#   'designation': 'Alta Barrancas Vineyards',
#   'points': 94,
#   'price': 50.0,
#   'province': 'Mendoza Province',
#   'region': 'Mendoza',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Pascual Toso'},
#  {'ID': 327,
#   'country': 'France',
#   'designation': 'Garrus',
#   'points': 94,
#   'price': 100.0,
#   'province': 'Provence',
#   'region': 'Côtes de Provence',
#   'variety': 'Rosé',
#   'winery': "Château d'Esclans"},
#  {'ID': 328,
#   'country': 'France',
#   'designation': 'Cuvée Marguerite Massaut',
#   'points': 94,
#   'price': 70.0,
#   'province': 'Southwest France',
#   'region': 'Cahors',
#   'variety': 'Malbec',
#   'winery': 'Château Lagrézette'},
# ...
#   'winery': 'Ferllen'},
#  {'ID': 1598,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 87,
#   'price': 140.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Tenuta di Sesta'},
#  {'ID': 1599,
#   'country': 'Italy',
#   'designation': 'Due Sorelle Riserva',
#   'points': 87,
#   'price': 60.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Tenuta La Fuga'},
#  {'ID': 1600,
#   'country': 'Italy',
#   'designation': 'Emilio Primo',
#   'points': 87,
#   'price': 25.0,
#   'province': 'Tuscany',
#   'region': 'Bolgheri',
#   'variety': 'Red Blend',
#   'winery': 'Terre del Marchesato'},
#  {'ID': 1602,
#   'country': 'Italy',
#   'designation': 'Ripe al Convento Riserva',
#   'points': 87,
#   'price': 138.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Castelgiocondo'},
#  {'ID': 1606,
#   'country': 'US',
#   'designation': 'Cutthroat Blend',
#   'points': 87,
#   'price': 35.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Red Blend',
#   'winery': 'Flying Trout'},
#  {'ID': 1607,
#   'country': 'US',
#   'designation': 'Mélange Blanc',
#   'points': 87,
#   'price': 23.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'White Blend',
#   'winery': 'Patterson'},
#  {'ID': 1608,
#   'country': 'France',
#   'designation': 'Château Courbian',
#   'points': 87,
#   'price': 19.0,
#   'province': 'Bordeaux',
#   'region': 'Médoc',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Producta Vignobles'},
#  {'ID': 1610,
#   'country': 'US',
#   'designation': 'Sofia Blanc de Blancs',
#   'points': 87,
#   'price': 19.0,
#   'province': 'California',
#   'region': 'Monterey County',
#   'variety': 'Sparkling Blend',
#   'winery': 'Francis Ford Coppola'},
#  {'ID': 1612,
#   'country': 'US',
#   'designation': 'Springline Super Tuscan-style',
#   'points': 87,
#   'price': 19.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'White Blend',
#   'winery': 'Genoa'},
#  {'ID': 1613,
#   'country': 'US',
#   'designation': 'Bacigalupi Vineyard',
#   'points': 87,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Graton Ridge'},
#  {'ID': 1614,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 87,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Gewürztraminer',
#   'winery': 'Navarro'},
#  {'ID': 1615,
#   'country': 'US',
#   'designation': 'Sharp Sisters',
#   'points': 87,
#   'price': 26.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Red Blend',
#   'winery': 'Mercer'},
#  {'ID': 1617,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 87,
#   'price': 60.0,
#   'province': 'Washington',
#   'region': 'Columbia Gorge (WA)',
#   'variety': 'Syrah',
#   'winery': 'Syncline'},
#  {'ID': 1618,
#   'country': 'US',
#   'designation': 'Boushey Vineyard',
#   'points': 87,
#   'price': 25.0,
#   'province': 'Washington',
#   'region': 'Yakima Valley',
#   'variety': 'Grenache Blanc',
#   'winery': 'Syncline'},
#  {'ID': 1620,
#   'country': 'France',
#   'designation': 'Brut Prestige',
#   'points': 91,
#   'price': 66.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Champagne Blend',
#   'winery': 'Charles Ellner'},
#  {'ID': 1622,
#   'country': 'France',
#   'designation': 'Brut Nature',
#   'points': 91,
#   'price': 75.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Champagne Blend',
#   'winery': 'Ayala'},
#  {'ID': 1623,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 25.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Fattoria La Ripa'},
#  {'ID': 1624,
#   'country': 'US',
#   'designation': 'Special Reserve',
#   'points': 90,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Herzog'},
#  {'ID': 1625,
#   'country': 'US',
#   'designation': 'Estate Grown Cave Fermented',
#   'points': 90,
#   'price': 95.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Merlot',
#   'winery': 'Jarvis'},
#  {'ID': 1626,
#   'country': 'US',
#   'designation': 'Sierra Madre Vineyard',
#   'points': 90,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Santa Barbara County',
#   'variety': 'Pinot Noir',
#   'winery': 'La Montagne'},
#  {'ID': 1627,
#   'country': 'US',
#   'designation': 'Lachini Family Estate',
#   'points': 90,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Lachini'},
#  {'ID': 1628,
#   'country': 'US',
#   'designation': 'Serious',
#   'points': 90,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Lodi',
#   'variety': 'Zinfandel',
#   'winery': 'Macchia'},
#  {'ID': 1629,
#   'country': 'US',
#   'designation': 'Estate 25th Anniversary',
#   'points': 90,
#   'price': 28.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Chardonnay',
#   'winery': 'McIntyre Vineyards'},
#  {'ID': 1631,
#   'country': 'US',
#   'designation': 'Reed Vineyard',
#   'points': 90,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Mt. Harlan',
#   'variety': 'Pinot Noir',
#   'winery': 'Calera'},
#  {'ID': 1633,
#   'country': 'France',
#   'designation': 'Grande Réserve Brut',
#   'points': 90,
#   'price': 50.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Champagne Blend',
#   'winery': 'Charles Ellner'},
#  {'ID': 1634,
#   'country': 'France',
#   'designation': 'La Chêneraie',
#   'points': 90,
#   'price': 55.0,
#   'province': 'Bordeaux',
#   'region': 'Fronsac',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Jeandeman'},
#  {'ID': 1638,
#   'country': 'Italy',
#   'designation': 'Limne',
#   'points': 90,
#   'price': 19.0,
#   'province': 'Lombardy',
#   'region': 'Lugana',
#   'variety': 'Turbiana',
#   'winery': 'Tenuta Roveglia'},
#  {'ID': 1639,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 90,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Triumph Cellars'},
#  {'ID': 1642,
#   'country': 'US',
#   'designation': 'Dark & Brooding',
#   'points': 90,
#   'price': 54.0,
#   'province': 'California',
#   'region': 'Sonoma County',
#   'variety': 'Red Blend',
#   'winery': 'Palmeri'},
#  {'ID': 1644,
#   'country': 'US',
#   'designation': 'Pendulum',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Monterey County',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Baker & Brain'},
#  {'ID': 1645,
#   'country': 'US',
#   'designation': 'Bald Mountain Vineyard',
#   'points': 90,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Ben Lomond Mountain',
#   'variety': 'Chardonnay',
#   'winery': 'Beauregard'},
#  {'ID': 1650,
#   'country': 'US',
#   'designation': 'The Augur Kick On Ranch Vineyard',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Santa Barbara County',
#   'variety': 'Riesling',
#   'winery': 'j.brix'},
#  {'ID': 1651,
#   'country': 'US',
#   'designation': '1149 Rosé of',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Paso Robles Willow Creek District',
#   'variety': 'Mourvèdre',
#   'winery': 'Jada Vineyard & Winery'},
#  {'ID': 1653,
#   'country': 'US',
#   'designation': 'Brut Rosé',
#   'points': 88,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Arroyo Grande Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Laetitia'},
#  {'ID': 1654,
#   'country': 'US',
#   'designation': 'Rayhill Vineyard',
#   'points': 88,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Landmark'},
#  {'ID': 1656,
#   'country': 'Italy',
#   'designation': 'Quercegobbe',
#   'points': 88,
#   'price': 65.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Merlot',
#   'winery': 'Petra'},
#  {'ID': 1657,
#   'country': 'Italy',
#   'designation': 'Maurleo',
#   'points': 88,
#   'price': 19.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Pietro Beconcini'},
#  {'ID': 1658,
#   'country': 'Italy',
#   'designation': 'Lippo',
#   'points': 88,
#   'price': 28.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Pieve Santo Stefano'},
#  {'ID': 1661,
#   'country': 'US',
#   'designation': 'Dianthus',
#   'points': 88,
#   'price': 27.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Rosé',
#   'winery': 'Tablas Creek'},
#  {'ID': 1662,
#   'country': 'Italy',
#   'designation': 'Trasolo',
#   'points': 88,
#   'price': 120.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Merlot',
#   'winery': 'Tenuta Villa Trasqua'},
#  {'ID': 1664,
#   'country': 'France',
#   'designation': "Baron d'Ardeuil Vieilles Vignes",
#   'points': 88,
#   'price': 15.0,
#   'province': 'Southwest France',
#   'region': 'Buzet',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Vignerons de Buzet'},
#  {'ID': 1666,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 88,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Santa Cruz Mountains',
#   'variety': 'Chardonnay',
#   'winery': 'Wrights Station'},
#  {'ID': 1668,
#   'country': 'France',
#   'designation': 'Cuvée des Conti',
#   'points': 88,
#   'price': 16.0,
#   'province': 'Southwest France',
#   'region': 'Bergerac Sec',
#   'variety': 'Bordeaux-style White Blend',
#   'winery': 'Château Tour des Gendres'},
#  {'ID': 1669,
#   'country': 'France',
#   'designation': 'Château Bazin',
#   'points': 88,
#   'price': 45.0,
#   'province': 'Southwest France',
#   'region': 'Côtes du Marmandais',
#   'variety': 'Red Blend',
#   'winery': 'Cave du Marmandais'},
#  {'ID': 1670,
#   'country': 'Italy',
#   'designation': 'Serisè',
#   'points': 88,
#   'price': 22.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Ciliegiolo',
#   'winery': 'Cesani'},
#  {'ID': 1673,
#   'country': 'Italy',
#   'designation': 'Poggio ai Merli',
#   'points': 88,
#   'price': 110.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Merlot',
#   'winery': 'Castellare di Castellina'},
#  {'ID': 1674,
#   'country': 'Italy',
#   'designation': 'Non Confonditur',
#   'points': 88,
#   'price': 26.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Argiano'},
#  {'ID': 1675,
#   'country': 'US',
#   'designation': 'Hope',
#   'points': 88,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'California',
#   'variety': 'Red Blend',
#   'winery': 'Aver Family Vineyards'},
#  {'ID': 1677,
#   'country': 'US',
#   'designation': 'The Sheriff',
#   'points': 88,
#   'price': 36.0,
#   'province': 'California',
#   'region': 'Livermore Valley',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Vasco Urbano'},
#  {'ID': 1679,
#   'country': 'Spain',
#   'designation': 'Castillo de Albai Crianza',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Pagos del Rey'},
#  {'ID': 1682,
#   'country': 'US',
#   'designation': 'Alloro Vineyard',
#   'points': 88,
#   'price': 60.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Torii Mor'},
#  {'ID': 1684,
#   'country': 'US',
#   'designation': 'Upstream',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Lodi',
#   'variety': 'Zinfandel',
#   'winery': 'Watts'},
#  {'ID': 1690,
#   'country': 'US',
#   'designation': 'York Creek Vineyard',
#   'points': 88,
#   'price': 37.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Petite Sirah',
#   'winery': 'Elyse'},
#  {'ID': 1692,
#   'country': 'US',
#   'designation': 'Preston Vineyards',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Dry Creek Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Horse & Plow'},
#  {'ID': 1693,
#   'country': 'US',
#   'designation': 'Le Cigare Blanc Beeswax Vineyard',
#   'points': 88,
#   'price': 26.0,
#   'province': 'California',
#   'region': 'Arroyo Seco',
#   'variety': 'Rhône-style White Blend',
#   'winery': 'Bonny Doon'},
#  {'ID': 1698,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 88,
#   'price': 10.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Clos du Lac'},
#  {'ID': 1700,
#   'country': 'US',
#   'designation': 'Sexton Hill Vineyard',
#   'points': 88,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Balletto'},
#  {'ID': 1704,
#   'country': 'Spain',
#   'designation': 'Maceración Carbónica',
#   'points': 88,
#   'price': 16.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Dominio de Berzal'},
#  {'ID': 1705,
#   'country': 'Spain',
#   'designation': "AV14 Clos d'Englora",
#   'points': 88,
#   'price': 30.0,
#   'province': 'Catalonia',
#   'region': 'Montsant',
#   'variety': 'Red Blend',
#   'winery': 'Cellers Baronia del Montsant'},
#  {'ID': 1706,
#   'country': 'Spain',
#   'designation': 'Inspiración Las Canteras',
#   'points': 88,
#   'price': 25.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Bodegas Valdemar'},
#  {'ID': 1707,
#   'country': 'Spain',
#   'designation': 'Crianza',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Viña Herminia'},
#  {'ID': 1710,
#   'country': 'US',
#   'designation': 'DuPratt Vineyard Old Vine',
#   'points': 90,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Mendocino Ridge',
#   'variety': 'Zinfandel',
#   'winery': 'Steele'},
#  {'ID': 1713,
#   'country': 'France',
#   'designation': 'Maison du Villard',
#   'points': 90,
#   'price': 35.0,
#   'province': 'Burgundy',
#   'region': 'Pouilly-Fuissé',
#   'variety': 'Chardonnay',
#   'winery': 'Château de Lavernette'},
#  {'ID': 1714,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 90,
#   'price': 18.0,
#   'province': 'California',
#   'region': 'El Dorado',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Lava Cap'},
#  {'ID': 1716,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Shenandoah Valley (CA)',
#   'variety': 'Zinfandel',
#   'winery': 'Easton'},
#  {'ID': 1717,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Edna Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Edna Valley Vineyard'},
#  {'ID': 1719,
#   'country': 'US',
#   'designation': 'Erato De Portola Trail Vineyard',
#   'points': 90,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Temecula Valley',
#   'variety': 'Cabernet Franc',
#   'winery': 'Gershon Bachus'},
#  {'ID': 1720,
#   'country': 'US',
#   'designation': 'El Jabali Vineyard Brut Rosé',
#   'points': 90,
#   'price': 65.0,
#   'province': 'California',
#   'region': 'Sta. Rita Hills',
#   'variety': 'Sparkling Blend',
#   'winery': 'Alma Rosa'},
#  {'ID': 1721,
#   'country': 'US',
#   'designation': 'Collins Holystone Vineyard Old Vine',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'St. Helena',
#   'variety': 'Zinfandel',
#   'winery': 'Benessere'},
#  {'ID': 1722,
#   'country': 'US',
#   'designation': 'Makena',
#   'points': 90,
#   'price': 35.0,
#   'province': 'Oregon',
#   'region': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'BKB'},
#  {'ID': 1723,
#   'country': 'US',
#   'designation': 'Mortal Zin',
#   'points': 90,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Graveyard'},
#  {'ID': 1724,
#   'country': 'US',
#   'designation': 'Aatto',
#   'points': 90,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Adelaida District',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'kukkula'},
#  {'ID': 1726,
#   'country': 'US',
#   'designation': 'The Villain',
#   'points': 90,
#   'price': 34.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Syrah',
#   'winery': 'Shane Wines'},
#  ...]

# %% [markdown]
# The `json.load()` function takes care of reading the contents of the file and turning it into `Python` values. We don't need to create a reader and then convert the reader to a `list` like we did with `csv`. Similar, but different.
#
# And once we have the contents in a variable, we can look at the data using `display()`:

# %%
display(data)
# Out:
# [{'ID': 0,
#   'country': 'US',
#   'designation': "Martha's Vineyard",
#   'points': 96,
#   'price': 235.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Heitz'},
#  {'ID': 1,
#   'country': 'Spain',
#   'designation': 'Carodorum Selección Especial Reserva',
#   'points': 96,
#   'price': 110.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Bodega Carmen Rodríguez'},
#  {'ID': 2,
#   'country': 'US',
#   'designation': 'Special Selected Late Harvest',
#   'points': 96,
#   'price': 90.0,
#   'province': 'California',
#   'region': 'Knights Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Macauley'},
#  {'ID': 3,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 96,
#   'price': 65.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ponzi'},
#  {'ID': 4,
#   'country': 'France',
#   'designation': 'La Brûlade',
#   'points': 95,
#   'price': 66.0,
#   'province': 'Provence',
#   'region': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  {'ID': 5,
#   'country': 'Spain',
#   'designation': 'Numanthia',
#   'points': 95,
#   'price': 73.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Numanthia'},
#  {'ID': 6,
#   'country': 'Spain',
#   'designation': 'San Román',
#   'points': 95,
#   'price': 65.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Maurodos'},
#  {'ID': 7,
#   'country': 'Spain',
#   'designation': 'Carodorum Único Crianza',
#   'points': 95,
#   'price': 110.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Bodega Carmen Rodríguez'},
#  {'ID': 8,
#   'country': 'US',
#   'designation': 'Silice',
#   'points': 95,
#   'price': 65.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  {'ID': 9,
#   'country': 'US',
#   'designation': "Gap's Crown Vineyard",
#   'points': 95,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Blue Farm'},
#  {'ID': 10,
#   'country': 'Italy',
#   'designation': 'Ronco della Chiesa',
#   'points': 95,
#   'price': 80.0,
#   'province': 'Northeastern Italy',
#   'region': 'Collio',
#   'variety': 'Friulano',
#   'winery': 'Borgo del Tiglio'},
#  {'ID': 11,
#   'country': 'US',
#   'designation': 'Estate Vineyard Wadensvil Block',
#   'points': 95,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Ribbon Ridge',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  {'ID': 12,
#   'country': 'US',
#   'designation': 'Weber Vineyard',
#   'points': 95,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  {'ID': 13,
#   'country': 'France',
#   'designation': 'Château Montus Prestige',
#   'points': 95,
#   'price': 90.0,
#   'province': 'Southwest France',
#   'region': 'Madiran',
#   'variety': 'Tannat',
#   'winery': 'Vignobles Brumont'},
#  {'ID': 14,
#   'country': 'US',
#   'designation': 'Grace Vineyard',
#   'points': 95,
#   'price': 185.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine Serene'},
#  {'ID': 15,
#   'country': 'US',
#   'designation': 'Sigrid',
#   'points': 95,
#   'price': 90.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Bergström'},
#  {'ID': 16,
#   'country': 'US',
#   'designation': 'Rainin Vineyard',
#   'points': 95,
#   'price': 325.0,
#   'province': 'California',
#   'region': 'Diamond Mountain District',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Hall'},
#  {'ID': 17,
#   'country': 'Spain',
#   'designation': '6 Años Reserva Premium',
#   'points': 95,
#   'price': 80.0,
#   'province': 'Northern Spain',
#   'region': 'Ribera del Duero',
#   'variety': 'Tempranillo',
#   'winery': 'Valduero'},
#  {'ID': 18,
#   'country': 'France',
#   'designation': 'Le Pigeonnier',
#   'points': 95,
#   'price': 290.0,
#   'province': 'Southwest France',
#   'region': 'Cahors',
#   'variety': 'Malbec',
#   'winery': 'Château Lagrézette'},
#  {'ID': 19,
#   'country': 'US',
#   'designation': "Gap's Crown Vineyard",
#   'points': 95,
#   'price': 75.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Gary Farrell'},
#  {'ID': 20,
#   'country': 'US',
#   'designation': 'Grignolino',
#   'points': 95,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Rosé',
#   'winery': 'Heitz'},
#  {'ID': 21,
#   'country': 'Spain',
#   'designation': 'Prado Enea Gran Reserva',
#   'points': 95,
#   'price': 79.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Muga'},
#  {'ID': 22,
#   'country': 'Spain',
#   'designation': 'Termanthia',
#   'points': 95,
#   'price': 220.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Numanthia'},
#  {'ID': 23,
#   'country': 'US',
#   'designation': 'Giallo Solare',
#   'points': 95,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Edna Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Center of Effort'},
#  {'ID': 24,
#   'country': 'US',
#   'designation': 'R-Bar-R Ranch',
#   'points': 95,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Santa Cruz Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Comartin'},
#  {'ID': 26,
#   'country': 'US',
#   'designation': 'Shea Vineyard',
#   'points': 94,
#   'price': 62.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  {'ID': 27,
#   'country': 'US',
#   'designation': 'Abetina',
#   'points': 94,
#   'price': 105.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ponzi'},
#  {'ID': 28,
#   'country': 'US',
#   'designation': "Garys' Vineyard",
#   'points': 94,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Pinot Noir',
#   'winery': 'Roar'},
#  {'ID': 29,
#   'country': 'US',
#   'designation': 'The Funk Estate',
#   'points': 94,
#   'price': 60.0,
#   'province': 'Washington',
#   'region': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Saviah'},
#  {'ID': 31,
#   'country': 'US',
#   'designation': 'Babushka',
#   'points': 90,
#   'price': 37.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Zepaltas'},
#  {'ID': 33,
#   'country': 'France',
#   'designation': 'Nonpareil Trésor Rosé Brut',
#   'points': 90,
#   'price': 22.0,
#   'province': 'France Other',
#   'region': 'Vin Mousseux',
#   'variety': 'Sparkling Blend',
#   'winery': 'Bouvet-Ladubay'},
#  {'ID': 34,
#   'country': 'US',
#   'designation': 'Conner Lee Vineyard',
#   'points': 90,
#   'price': 42.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Chardonnay',
#   'winery': 'Buty'},
#  {'ID': 35,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 135.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Carillon'},
#  {'ID': 39,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 29.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Castello di Monterinaldi'},
#  {'ID': 40,
#   'country': 'Spain',
#   'designation': 'Amandi',
#   'points': 90,
#   'price': 17.0,
#   'province': 'Galicia',
#   'region': 'Ribeira Sacra',
#   'variety': 'Mencía',
#   'winery': 'Don Bernardino'},
#  {'ID': 41,
#   'country': 'Spain',
#   'designation': 'Alfonso Oloroso Seco',
#   'points': 90,
#   'price': 26.0,
#   'province': 'Andalucia',
#   'region': 'Jerez',
#   'variety': 'Palomino',
#   'winery': 'González Byass'},
#  {'ID': 43,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 39.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Rignana'},
#  {'ID': 44,
#   'country': 'France',
#   'designation': 'Coteaux',
#   'points': 90,
#   'price': 69.0,
#   'province': 'Rhône Valley',
#   'region': 'Cornas',
#   'variety': 'Syrah',
#   'winery': 'Tardieu-Laurent'},
#  {'ID': 45,
#   'country': 'Italy',
#   'designation': 'Vigneto Odoardo Beccari Riserva',
#   'points': 90,
#   'price': 30.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Vignavecchia'},
#  {'ID': 46,
#   'country': 'Italy',
#   'designation': 'Poggio alle Mura',
#   'points': 90,
#   'price': 90.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Banfi'},
#  {'ID': 47,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 90,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Brandlin'},
#  {'ID': 50,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 100.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Capanne Ricci'},
#  {'ID': 52,
#   'country': 'France',
#   'designation': 'Les 7 Hommes',
#   'points': 90,
#   'price': 42.0,
#   'province': 'Loire Valley',
#   'region': 'Sancerre',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Cherrier Frères'},
#  {'ID': 53,
#   'country': 'France',
#   'designation': "L'Inédit",
#   'points': 90,
#   'price': 28.0,
#   'province': 'Loire Valley',
#   'region': 'Coteaux du Giennois',
#   'variety': 'Pinot Noir',
#   'winery': 'Clement et Florian Berthier'},
#  {'ID': 55,
#   'country': 'US',
#   'designation': 'Four Flags',
#   'points': 90,
#   'price': 69.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'DeLille'},
#  {'ID': 57,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 90,
#   'price': 25.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Dr. Konstantin Frank'},
#  {'ID': 58,
#   'country': 'US',
#   'designation': 'Final Final',
#   'points': 90,
#   'price': 30.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Cabernet Sauvignon-Syrah',
#   'winery': 'Efeste'},
#  {'ID': 59,
#   'country': 'Italy',
#   'designation': 'Poggio Bestiale',
#   'points': 90,
#   'price': 60.0,
#   'province': 'Tuscany',
#   'region': 'Maremma Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Fattoria di Magliano'},
#  {'ID': 60,
#   'country': 'Argentina',
#   'designation': "The Apple Doesn't Fall Far From The Tree",
#   'points': 91,
#   'price': 30.0,
#   'province': 'Mendoza Province',
#   'region': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Matias Riccitelli'},
#  {'ID': 62,
#   'country': 'Argentina',
#   'designation': 'Alegoría Gran Reserva',
#   'points': 91,
#   'price': 25.0,
#   'province': 'Mendoza Province',
#   'region': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Navarro Correas'},
#  {'ID': 63,
#   'country': 'France',
#   'designation': "L'Homme Mort Premier Cru",
#   'points': 91,
#   'price': 45.0,
#   'province': 'Burgundy',
#   'region': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Chenevières'},
#  {'ID': 65,
#   'country': 'US',
#   'designation': 'Estate Select',
#   'points': 91,
#   'price': 36.0,
#   'province': 'California',
#   'region': 'Santa Clara Valley',
#   'variety': 'Syrah',
#   'winery': 'Jason-Stephens'},
#  {'ID': 66,
#   'country': 'France',
#   'designation': 'Fourchaume Premier Cru',
#   'points': 91,
#   'price': 38.0,
#   'province': 'Burgundy',
#   'region': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Louis Max'},
#  {'ID': 67,
#   'country': 'US',
#   'designation': 'Animo',
#   'points': 91,
#   'price': 85.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Michael Mondavi Family Estate'},
#  {'ID': 68,
#   'country': 'US',
#   'designation': 'Schindler Vineyard',
#   'points': 91,
#   'price': 50.0,
#   'province': 'Oregon',
#   'region': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Panther Creek'},
#  {'ID': 69,
#   'country': 'US',
#   'designation': 'Barrel Select',
#   'points': 91,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Rutherford',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Provenance Vineyards'},
#  {'ID': 70,
#   'country': 'US',
#   'designation': 'District Collection',
#   'points': 91,
#   'price': 85.0,
#   'province': 'California',
#   'region': 'St. Helena',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Raymond'},
#  {'ID': 75,
#   'country': 'US',
#   'designation': 'Premier Cuvée',
#   'points': 91,
#   'price': 54.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Archery Summit'},
#  {'ID': 76,
#   'country': 'France',
#   'designation': "Le Nombre d'Or Brut Nature",
#   'points': 91,
#   'price': 85.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Chardonnay',
#   'winery': 'Aubry'},
#  {'ID': 77,
#   'country': 'US',
#   'designation': 'Juliana Vineyard',
#   'points': 91,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'B Cellars'},
#  {'ID': 79,
#   'country': 'Italy',
#   'designation': 'Boscato',
#   'points': 91,
#   'price': 75.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Bel Colle'},
#  {'ID': 80,
#   'country': 'US',
#   'designation': 'Aeolian',
#   'points': 91,
#   'price': 42.0,
#   'province': 'Oregon',
#   'region': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Bethel Heights'},
#  {'ID': 83,
#   'country': 'Italy',
#   'designation': "del Comune di Serralunga d'Alba",
#   'points': 91,
#   'price': 59.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina Cucco'},
#  {'ID': 84,
#   'country': 'Italy',
#   'designation': 'Bricco Luciani',
#   'points': 91,
#   'price': 85.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina del Monastero'},
#  {'ID': 85,
#   'country': 'Italy',
#   'designation': 'Bricco Gattera',
#   'points': 91,
#   'price': 80.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cordero di Montezemolo'},
#  {'ID': 86,
#   'country': 'France',
#   'designation': 'Montmains Premier Cru',
#   'points': 91,
#   'price': 45.0,
#   'province': 'Burgundy',
#   'region': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Gérard Duplessis'},
#  {'ID': 88,
#   'country': 'US',
#   'designation': 'Bacigalupi Vineyard',
#   'points': 91,
#   'price': 65.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Eleven Eleven'},
#  {'ID': 89,
#   'country': 'US',
#   'designation': 'Magnificat',
#   'points': 91,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Meritage',
#   'winery': 'Franciscan'},
#  {'ID': 92,
#   'country': 'Italy',
#   'designation': 'Nature',
#   'points': 86,
#   'price': 22.0,
#   'province': 'Veneto',
#   'region': 'Prosecco',
#   'variety': 'Glera',
#   'winery': 'De Stefani'},
#  {'ID': 93,
#   'country': 'US',
#   'designation': 'Small Lot Blend',
#   'points': 86,
#   'price': 13.0,
#   'province': 'California',
#   'region': 'Mendocino County',
#   'variety': 'Chardonnay',
#   'winery': 'Parducci'},
#  {'ID': 95,
#   'country': 'France',
#   'designation': 'Château Beauvillain-Monpezat',
#   'points': 86,
#   'price': 14.0,
#   'province': 'Southwest France',
#   'region': 'Cahors',
#   'variety': 'Malbec-Merlot',
#   'winery': 'Rigal'},
#  {'ID': 98,
#   'country': 'France',
#   'designation': 'Pigmentum',
#   'points': 86,
#   'price': 15.0,
#   'province': 'Southwest France',
#   'region': 'Buzet',
#   'variety': 'Merlot-Malbec',
#   'winery': 'Georges Vigouroux'},
#  {'ID': 99,
#   'country': 'France',
#   'designation': 'Pigmentum',
#   'points': 86,
#   'price': 10.0,
#   'province': 'Southwest France',
#   'region': 'Côtes de Gascogne',
#   'variety': 'Ugni Blanc-Colombard',
#   'winery': 'Georges Vigouroux'},
#  {'ID': 101,
#   'country': 'US',
#   'designation': 'Stephanie',
#   'points': 86,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Hestan'},
#  {'ID': 103,
#   'country': 'US',
#   'designation': "Bella's Blend",
#   'points': 86,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Knights Valley',
#   'variety': 'Cabernet Sauvignon-Cabernet Franc',
#   'winery': 'Ehret'},
#  {'ID': 104,
#   'country': 'US',
#   'designation': 'Tears of Dew Late Harvest',
#   'points': 86,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Moscato',
#   'winery': 'EOS'},
#  {'ID': 105,
#   'country': 'US',
#   'designation': 'Tudor Hills Vineyard',
#   'points': 86,
#   'price': 17.0,
#   'province': 'Washington',
#   'region': 'Yakima Valley',
#   'variety': 'Pinot Grigio',
#   'winery': 'Martinez & Martinez'},
#  {'ID': 109,
#   'country': 'US',
#   'designation': 'Homestead Block',
#   'points': 86,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Kuleto Estate'},
#  {'ID': 111,
#   'country': 'Argentina',
#   'designation': 'Terroir Único Pinot Noir',
#   'points': 86,
#   'price': 12.0,
#   'province': 'Mendoza Province',
#   'region': 'Tupungato',
#   'variety': 'Rosé',
#   'winery': 'Zorzal'},
#  {'ID': 112,
#   'country': 'US',
#   'designation': 'Limited Release Cold Springs Vineyard',
#   'points': 86,
#   'price': 125.0,
#   'province': 'California',
#   'region': 'Howell Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Charles Krug'},
#  {'ID': 113,
#   'country': 'US',
#   'designation': 'Castle Hill Vineyard',
#   'points': 86,
#   'price': 25.0,
#   'province': 'New York',
#   'region': 'Hudson River Region',
#   'variety': 'Riesling',
#   'winery': 'Millbrook'},
#  {'ID': 115,
#   'country': 'Argentina',
#   'designation': 'Reserva',
#   'points': 86,
#   'price': 15.0,
#   'province': 'Mendoza Province',
#   'region': 'Valle de Uco',
#   'variety': 'Malbec',
#   'winery': 'Viñalba'},
#  {'ID': 120,
#   'country': 'US',
#   'designation': 'The Flyer',
#   'points': 91,
#   'price': 59.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'MacPhail'},
#  {'ID': 121,
#   'country': 'US',
#   'designation': 'Charles Vineyard Clone 05',
#   'points': 91,
#   'price': 49.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Foursight'},
#  {'ID': 122,
#   'country': 'US',
#   'designation': 'Solomon Hills Vineyard Rosé',
#   'points': 91,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Santa Maria Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Goat Bubbles'},
#  {'ID': 123,
#   'country': 'US',
#   'designation': 'Paris Tasting Commemorative',
#   'points': 91,
#   'price': 93.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Grgich Hills'},
#  {'ID': 124,
#   'country': 'US',
#   'designation': "Methode a l'Ancienne",
#   'points': 91,
#   'price': 32.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Navarro'},
#  {'ID': 126,
#   'country': 'US',
#   'designation': 'Grand Wren',
#   'points': 90,
#   'price': 100.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Zinfandel',
#   'winery': 'Renwood'},
#  {'ID': 127,
#   'country': 'US',
#   'designation': 'Central Park West Vineyard',
#   'points': 90,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'St. Helena',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Trinchero'},
#  {'ID': 128,
#   'country': 'Spain',
#   'designation': 'Arnegui Reserva',
#   'points': 90,
#   'price': 22.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Pagos del Rey'},
#  {'ID': 129,
#   'country': 'Italy',
#   'designation': 'Chianta Bianco',
#   'points': 90,
#   'price': 45.0,
#   'province': 'Sicily & Sardinia',
#   'region': 'Etna',
#   'variety': 'White Blend',
#   'winery': 'Biondi'},
#  {'ID': 132,
#   'country': 'US',
#   'designation': 'Cooper Ranch',
#   'points': 90,
#   'price': 26.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Barbera',
#   'winery': 'Andis'},
#  {'ID': 134,
#   'country': 'US',
#   'designation': 'Longwood',
#   'points': 90,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Beaucanon'},
#  {'ID': 135,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 90,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Adelaida District',
#   'variety': 'Grenache',
#   'winery': 'Brecon Estate'},
#  {'ID': 136,
#   'country': 'US',
#   'designation': 'Mustang Springs',
#   'points': 90,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Adelaida District',
#   'variety': 'Zinfandel',
#   'winery': 'Peachy Canyon'},
#  {'ID': 137,
#   'country': 'US',
#   'designation': 'SMC',
#   'points': 90,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'California',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Three'},
#  {'ID': 138,
#   'country': 'Spain',
#   'designation': 'Crianza',
#   'points': 90,
#   'price': 17.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Valdelacierva'},
#  {'ID': 139,
#   'country': 'France',
#   'designation': 'Le',
#   'points': 90,
#   'price': 18.0,
#   'province': 'Languedoc-Roussillon',
#   'region': 'Coteaux du Languedoc Pic Saint Loup',
#   'variety': 'Rosé',
#   'winery': 'Château de Lancyre'},
#  {'ID': 141,
#   'country': 'US',
#   'designation': 'Rte Blanc',
#   'points': 90,
#   'price': 28.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Clif Family'},
#  {'ID': 142,
#   'country': 'US',
#   'designation': 'Hook Vineyard',
#   'points': 90,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Grenache',
#   'winery': 'Santa Cruz Mountain Vineyard'},
#  {'ID': 144,
#   'country': 'US',
#   'designation': 'Jespersen Ranch',
#   'points': 90,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Edna Valley',
#   'variety': 'Albariño',
#   'winery': 'Stephen Ross'},
#  {'ID': 146,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 90,
#   'price': 36.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Grgich Hills'},
#  {'ID': 152,
#   'country': 'Spain',
#   'designation': 'Brut Reserva',
#   'points': 89,
#   'price': 17.0,
#   'province': 'Catalonia',
#   'region': 'Cava',
#   'variety': 'Sparkling Blend',
#   'winery': 'Bohigas'},
#  {'ID': 158,
#   'country': 'Spain',
#   'designation': 'Viña Real Gran Reserva',
#   'points': 89,
#   'price': 44.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'CVNE'},
#  {'ID': 160,
#   'country': 'US',
#   'designation': 'Range 30 West',
#   'points': 89,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Happy Canyon of Santa Barbara',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Foxen 7200'},
#  {'ID': 162,
#   'country': 'Spain',
#   'designation': 'Gaudium',
#   'points': 89,
#   'price': 44.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Marqués de Cáceres'},
#  {'ID': 164,
#   'country': 'US',
#   'designation': 'Mill Road Vineyard',
#   'points': 89,
#   'price': 23.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Viognier',
#   'winery': 'Eberle'},
#  {'ID': 165,
#   'country': 'US',
#   'designation': 'Freedom Hill Vineyard',
#   'points': 89,
#   'price': 36.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Silvan Ridge'},
#  {'ID': 166,
#   'country': 'Italy',
#   'designation': 'Le Redini',
#   'points': 89,
#   'price': 25.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Tenuta degli Dei'},
#  {'ID': 167,
#   'country': 'Italy',
#   'designation': 'Il Guardiano',
#   'points': 89,
#   'price': 22.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Poggio Mandorlo'},
#  {'ID': 169,
#   'country': 'US',
#   'designation': 'Del Arroyo Vineyard',
#   'points': 89,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Livermore Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Occasio'},
#  {'ID': 173,
#   'country': 'US',
#   'designation': 'Charles Vineyard Clone O5',
#   'points': 89,
#   'price': 49.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Foursight'},
#  {'ID': 174,
#   'country': 'France',
#   'designation': 'Héritages Elevé en Foudres de Chêne',
#   'points': 89,
#   'price': 16.0,
#   'province': 'Rhône Valley',
#   'region': 'Côtes du Rhône',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Ogier'},
#  {'ID': 175,
#   'country': 'Spain',
#   'designation': 'Gran Bajoz',
#   'points': 89,
#   'price': 30.0,
#   'province': 'Northern Spain',
#   'region': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Pagos del Rey'},
#  {'ID': 176,
#   'country': 'Italy',
#   'designation': 'Palazzo Altesi',
#   'points': 89,
#   'price': 40.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Sangiovese',
#   'winery': 'Altesino'},
#  {'ID': 177,
#   'country': 'Italy',
#   'designation': 'Il Borgo',
#   'points': 89,
#   'price': 57.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Cabreo'},
#  {'ID': 178,
#   'country': 'US',
#   'designation': 'Lot 525',
#   'points': 89,
#   'price': 29.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Cameron Hughes'},
#  {'ID': 181,
#   'country': 'US',
#   'designation': 'Estate Reserve',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Syrah',
#   'winery': 'San Simeon'},
#  {'ID': 182,
#   'country': 'US',
#   'designation': 'Sonatera Vineyard',
#   'points': 88,
#   'price': 49.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Siduri'},
#  {'ID': 183,
#   'country': 'US',
#   'designation': 'Boushey Vineyard',
#   'points': 88,
#   'price': 20.0,
#   'province': 'Washington',
#   'region': 'Yakima Valley',
#   'variety': 'Picpoul',
#   'winery': 'Syncline'},
#  {'ID': 184,
#   'country': 'Argentina',
#   'designation': 'Trinità Grand Reserve',
#   'points': 88,
#   'price': 26.0,
#   'province': 'Mendoza Province',
#   'region': 'Luján de Cuyo',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Piattelli'},
#  {'ID': 185,
#   'country': 'US',
#   'designation': 'Entwined',
#   'points': 88,
#   'price': 34.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Pondera'},
#  {'ID': 186,
#   'country': 'US',
#   'designation': 'French Camp Vineyard',
#   'points': 88,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Tobin James'},
#  {'ID': 187,
#   'country': 'US',
#   'designation': 'French Camp Vineyard',
#   'points': 88,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Tobin James'},
#  {'ID': 188,
#   'country': 'Spain',
#   'designation': 'Sobre Lías',
#   'points': 88,
#   'price': 25.0,
#   'province': 'Northern Spain',
#   'region': 'Valdeorras',
#   'variety': 'Godello',
#   'winery': 'Valdesil'},
#  {'ID': 189,
#   'country': 'Spain',
#   'designation': 'Negre',
#   'points': 87,
#   'price': 22.0,
#   'province': 'Catalonia',
#   'region': 'Montsant',
#   'variety': 'Red Blend',
#   'winery': 'Jaspi'},
#  {'ID': 190,
#   'country': 'Argentina',
#   'designation': 'Reserve',
#   'points': 87,
#   'price': 15.0,
#   'province': 'Mendoza Province',
#   'region': 'Tupungato',
#   'variety': 'Malbec',
#   'winery': 'Tupun'},
#  {'ID': 197,
#   'country': 'US',
#   'designation': 'Rosé of',
#   'points': 87,
#   'price': 18.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Malbec',
#   'winery': 'Hamilton'},
#  {'ID': 198,
#   'country': 'US',
#   'designation': 'Ingle Vineyard Unoaked',
#   'points': 87,
#   'price': 18.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Chardonnay',
#   'winery': 'Heron Hill'},
#  {'ID': 199,
#   'country': 'US',
#   'designation': 'Semi-Dry',
#   'points': 87,
#   'price': 14.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Heron Hill'},
#  {'ID': 200,
#   'country': 'US',
#   'designation': 'Semi-Dry',
#   'points': 87,
#   'price': 14.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Fox Run'},
#  {'ID': 201,
#   'country': 'US',
#   'designation': 'Ice Wine',
#   'points': 87,
#   'price': 40.0,
#   'province': 'New York',
#   'region': 'Finger Lakes',
#   'variety': 'Cabernet Franc',
#   'winery': 'Glenora'},
#  {'ID': 208,
#   'country': 'US',
#   'designation': 'Weinbau',
#   'points': 87,
#   'price': 32.0,
#   'province': 'Washington',
#   'region': 'Wahluke Slope',
#   'variety': 'Grenache',
#   'winery': 'Sol Stone'},
#  {'ID': 209,
#   'country': 'Spain',
#   'designation': 'Yá Cuvée 23 Brut Rosé',
#   'points': 87,
#   'price': 18.0,
#   'province': 'Catalonia',
#   'region': 'Cava',
#   'variety': 'Sparkling Blend',
#   'winery': 'Sumarroca'},
#  {'ID': 211,
#   'country': 'Italy',
#   'designation': 'Nervo',
#   'points': 93,
#   'price': 49.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Rizzi'},
#  {'ID': 212,
#   'country': 'US',
#   'designation': 'Rocky Ridge Vineyard',
#   'points': 93,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Rockpile',
#   'variety': 'Zinfandel',
#   'winery': 'Robert Biale'},
#  {'ID': 213,
#   'country': 'Italy',
#   'designation': 'Fausoni',
#   'points': 93,
#   'price': 58.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Sottimano'},
#  {'ID': 214,
#   'country': 'France',
#   'designation': 'Rosacker Grand Cru',
#   'points': 93,
#   'price': 39.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Jean-Luc Mader'},
#  {'ID': 215,
#   'country': 'France',
#   'designation': 'Clos Häuserer Wintzenheim',
#   'points': 93,
#   'price': 65.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Zind-Humbrecht'},
#  {'ID': 218,
#   'country': 'France',
#   'designation': 'Pfingstberg Paradis Grand Cru',
#   'points': 93,
#   'price': 42.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine François Schmitt'},
#  {'ID': 219,
#   'country': 'France',
#   'designation': 'Altenberg de Bergheim Grand Cru Vieilles Vignes',
#   'points': 93,
#   'price': 61.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Gustave Lorentz'},
#  {'ID': 220,
#   'country': 'US',
#   'designation': 'Collaboration Series VI Ciel du Cheval Vineyard',
#   'points': 93,
#   'price': 58.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'G-S-M',
#   'winery': 'Force Majeure'},
#  {'ID': 221,
#   'country': 'US',
#   'designation': 'Hastings Ranch Vineyard',
#   'points': 93,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Mourvèdre',
#   'winery': 'Anglim'},
#  {'ID': 222,
#   'country': 'France',
#   'designation': 'Heissenberg',
#   'points': 93,
#   'price': 48.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Ostertag'},
#  {'ID': 223,
#   'country': 'US',
#   'designation': 'Stagecoach Vineyards The Biale Block',
#   'points': 93,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Robert Biale'},
#  {'ID': 224,
#   'country': 'Italy',
#   'designation': 'Pajorè',
#   'points': 93,
#   'price': 58.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Sottimano'},
#  {'ID': 226,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 93,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Fort Ross-Seaview',
#   'variety': 'Syrah',
#   'winery': 'Red Car'},
#  {'ID': 227,
#   'country': 'US',
#   'designation': 'Collaboration Series V Ciel du Cheval Vineyard',
#   'points': 93,
#   'price': 80.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Force Majeure'},
#  {'ID': 228,
#   'country': 'US',
#   'designation': 'White Hawk Vineyard',
#   'points': 93,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Santa Barbara County',
#   'variety': 'Syrah',
#   'winery': 'Mulvane Wine Co.'},
#  {'ID': 230,
#   'country': 'US',
#   'designation': 'Double Canyon Vineyard',
#   'points': 93,
#   'price': 48.0,
#   'province': 'Washington',
#   'region': 'Horse Heaven Hills',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Double Canyon'},
#  {'ID': 231,
#   'country': 'US',
#   'designation': 'Red Rock Terrace',
#   'points': 93,
#   'price': 200.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Diamond Creek'},
#  {'ID': 232,
#   'country': 'US',
#   'designation': 'Ciel du Cheval Vineyard',
#   'points': 93,
#   'price': 39.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Petit Verdot',
#   'winery': 'Côtes de Ciel'},
#  {'ID': 233,
#   'country': 'US',
#   'designation': 'Kingpin',
#   'points': 93,
#   'price': 62.0,
#   'province': 'Washington',
#   'region': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Sparkman'},
#  {'ID': 235,
#   'country': 'France',
#   'designation': 'Domaine Saint-Rémy Schlosberg Grand Cru',
#   'points': 92,
#   'price': 35.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Ehrhart'},
#  {'ID': 236,
#   'country': 'France',
#   'designation': 'Pfersigberg Grand Cru',
#   'points': 92,
#   'price': 48.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Zinck'},
#  {'ID': 237,
#   'country': 'France',
#   'designation': 'Calcaire',
#   'points': 92,
#   'price': 55.0,
#   'province': 'Alsace',
#   'region': 'Alsace',
#   'variety': 'Riesling',
#   'winery': 'Domaine Zind-Humbrecht'},
#  {'ID': 239,
#   'country': 'Italy',
#   'designation': 'Coste Rubin',
#   'points': 92,
#   'price': 69.0,
#   'province': 'Piedmont',
#   'region': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Fontanafredda'},
#  {'ID': 246,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 88,
#   'price': 36.0,
#   'province': 'Oregon',
#   'region': 'McMinnville',
#   'variety': 'Pinot Noir',
#   'winery': 'Coeur de Terre'},
#  {'ID': 248,
#   'country': 'US',
#   'designation': 'Limited Selection',
#   'points': 88,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Central Coast',
#   'variety': 'Chardonnay',
#   'winery': 'Daniel Gehrs'},
#  {'ID': 249,
#   'country': 'US',
#   'designation': "Cuvée Luke Saralee's Vineyard",
#   'points': 88,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Rhône-style White Blend',
#   'winery': 'Davis Family'},
#  {'ID': 252,
#   'country': 'US',
#   'designation': "Wits' End",
#   'points': 88,
#   'price': 60.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Roco'},
#  {'ID': 253,
#   'country': 'US',
#   'designation': 'Toyon Farm',
#   'points': 88,
#   'price': 54.0,
#   'province': 'California',
#   'region': 'Carneros',
#   'variety': 'Pinot Noir',
#   'winery': 'Saintsbury'},
#  {'ID': 254,
#   'country': 'US',
#   'designation': 'Early',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Muscat',
#   'winery': 'Silvan Ridge'},
#  {'ID': 255,
#   'country': 'Italy',
#   'designation': 'Bussia',
#   'points': 88,
#   'price': 56.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Silvano Bolmida'},
#  {'ID': 256,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 88,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'St. Supéry'},
#  {'ID': 257,
#   'country': 'US',
#   'designation': 'Guidotti Vineyard',
#   'points': 88,
#   'price': 61.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Pinot Noir',
#   'winery': 'Testarossa'},
#  {'ID': 259,
#   'country': 'Spain',
#   'designation': 'Prestigio',
#   'points': 88,
#   'price': 30.0,
#   'province': 'Northern Spain',
#   'region': 'Cigales',
#   'variety': 'Tempranillo',
#   'winery': 'Val de Los Frailes'},
#  {'ID': 260,
#   'country': 'Spain',
#   'designation': 'Crianza',
#   'points': 88,
#   'price': 17.0,
#   'province': 'Central Spain',
#   'region': 'La Mancha',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Yuntero'},
#  {'ID': 262,
#   'country': 'US',
#   'designation': 'Querida',
#   'points': 88,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Cabernet Sauvignon-Merlot',
#   'winery': 'Oso Libre'},
#  {'ID': 263,
#   'country': 'US',
#   'designation': 'Primoroso',
#   'points': 88,
#   'price': 39.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Red Blend',
#   'winery': 'Oso Libre'},
#  {'ID': 264,
#   'country': 'Italy',
#   'designation': "del Comune di Serralunga d'Alba",
#   'points': 88,
#   'price': 49.0,
#   'province': 'Piedmont',
#   'region': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Palladino'},
#  {'ID': 265,
#   'country': 'France',
#   'designation': 'Domaine de Saint-Pierre',
#   'points': 88,
#   'price': 23.0,
#   'province': 'Loire Valley',
#   'region': 'Sancerre',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Pierre Prieur et Fils'},
#  {'ID': 267,
#   'country': 'US',
#   'designation': "Anna's Estate Vineyard",
#   'points': 88,
#   'price': 32.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Mourvèdre',
#   'winery': 'Adelaida'},
#  {'ID': 269,
#   'country': 'Argentina',
#   'designation': 'Single Vineyard Reserva',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Mendoza Province',
#   'region': 'Agrelo',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Lamadrid'},
#  {'ID': 270,
#   'country': 'France',
#   'designation': 'Pertuisots Premier Cru',
#   'points': 92,
#   'price': 92.0,
#   'province': 'Burgundy',
#   'region': 'Beaune',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine de Bellene'},
#  {'ID': 271,
#   'country': 'France',
#   'designation': 'Clos du Cailleret Premier Cru',
#   'points': 92,
#   'price': 94.0,
#   'province': 'Burgundy',
#   'region': 'Chassagne-Montrachet',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Vincent Girardin'},
#  {'ID': 272,
#   'country': 'US',
#   'designation': 'Haynes Vineyard',
#   'points': 92,
#   'price': 58.0,
#   'province': 'California',
#   'region': 'Coombsville',
#   'variety': 'Chardonnay',
#   'winery': 'Failla'},
#  {'ID': 273,
#   'country': 'US',
#   'designation': 'Suzuri Series Shake Ridge Ranch',
#   'points': 92,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Gallica'},
#  {'ID': 274,
#   'country': 'US',
#   'designation': 'Vintage Brut',
#   'points': 92,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'J Vineyards & Winery'},
#  {'ID': 276,
#   'country': 'Italy',
#   'designation': 'Sirmian',
#   'points': 92,
#   'price': 27.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Pinot Bianco',
#   'winery': 'Nals Margreid'},
#  {'ID': 279,
#   'country': 'US',
#   'designation': 'Solomon Hills Vineyard',
#   'points': 92,
#   'price': 43.0,
#   'province': 'California',
#   'region': 'Santa Maria Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ryan Cochrane'},
#  {'ID': 280,
#   'country': 'Italy',
#   'designation': 'Monte Carbonare',
#   'points': 92,
#   'price': 33.0,
#   'province': 'Veneto',
#   'region': 'Soave Classico',
#   'variety': 'Garganega',
#   'winery': 'Suavia'},
#  {'ID': 281,
#   'country': 'Italy',
#   'designation': 'Quarz',
#   'points': 92,
#   'price': 60.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Sauvignon',
#   'winery': 'Cantina Terlano'},
#  {'ID': 283,
#   'country': 'France',
#   'designation': 'Réserve',
#   'points': 92,
#   'price': 30.0,
#   'province': 'Bordeaux',
#   'region': 'Graves',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Haut Selve'},
#  {'ID': 284,
#   'country': 'US',
#   'designation': 'Lampyridae Vineyards',
#   'points': 92,
#   'price': 100.0,
#   'province': 'California',
#   'region': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Communication Block'},
#  {'ID': 285,
#   'country': 'US',
#   'designation': 'Le Mistral Vineyard',
#   'points': 92,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Monterey County',
#   'variety': 'Syrah',
#   'winery': 'Baker & Brain'},
#  {'ID': 286,
#   'country': 'France',
#   'designation': 'Les Charmes Dessus',
#   'points': 91,
#   'price': 60.0,
#   'province': 'Burgundy',
#   'region': 'Santenay',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine de Bellene'},
#  {'ID': 287,
#   'country': 'France',
#   'designation': 'Cuvée Germain',
#   'points': 91,
#   'price': 16.0,
#   'province': 'Southwest France',
#   'region': 'Côtes du Tarn',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': "Domaine D'en Ségur"},
#  {'ID': 288,
#   'country': 'France',
#   'designation': 'Quintessence',
#   'points': 91,
#   'price': 40.0,
#   'province': 'Burgundy',
#   'region': 'Pouilly-Fuissé',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Sangouard-Guyot'},
#  {'ID': 289,
#   'country': 'US',
#   'designation': 'Clay Court',
#   'points': 91,
#   'price': 60.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Elk Cove'},
#  {'ID': 293,
#   'country': 'US',
#   'designation': 'Kruse Vineyards',
#   'points': 91,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Syrah',
#   'winery': 'Jack Creek'},
#  {'ID': 295,
#   'country': 'US',
#   'designation': 'Rosé of',
#   'points': 91,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Brick & Mortar'},
#  {'ID': 296,
#   'country': 'Italy',
#   'designation': 'Prail',
#   'points': 91,
#   'price': 25.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Sauvignon',
#   'winery': 'Colterenzio'},
#  {'ID': 297,
#   'country': 'Italy',
#   'designation': 'Puiten',
#   'points': 91,
#   'price': 23.0,
#   'province': 'Northeastern Italy',
#   'region': 'Alto Adige',
#   'variety': 'Pinot Grigio',
#   'winery': 'Colterenzio'},
#  {'ID': 298,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 91,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Carneros',
#   'variety': 'Pinot Noir',
#   'winery': 'Cuvaison'},
#  {'ID': 299,
#   'country': 'US',
#   'designation': 'Nova Vineyard',
#   'points': 91,
#   'price': 32.0,
#   'province': 'California',
#   'region': 'Clear Lake',
#   'variety': 'Zinfandel',
#   'winery': 'De Loach'},
#  {'ID': 300,
#   'country': 'US',
#   'designation': 'The Funk Estate',
#   'points': 94,
#   'price': 60.0,
#   'province': 'Washington',
#   'region': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Saviah'},
#  {'ID': 301,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 94,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Riesling',
#   'winery': 'Smith-Madrone'},
#  {'ID': 302,
#   'country': 'Italy',
#   'designation': "Vigneto Monte Sant'Urbano",
#   'points': 94,
#   'price': 85.0,
#   'province': 'Veneto',
#   'region': 'Amarone della Valpolicella Classico',
#   'variety': 'Red Blend',
#   'winery': 'Speri'},
#  {'ID': 303,
#   'country': 'US',
#   'designation': 'White',
#   'points': 94,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Riesling',
#   'winery': 'Stony Hill'},
#  {'ID': 304,
#   'country': 'US',
#   'designation': 'Sierra Madre Vineyard',
#   'points': 94,
#   'price': 65.0,
#   'province': 'California',
#   'region': 'Santa Maria Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Testarossa'},
#  {'ID': 306,
#   'country': 'US',
#   'designation': 'Bergström Vineyard',
#   'points': 94,
#   'price': 90.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  {'ID': 307,
#   'country': 'US',
#   'designation': 'Angel Hawk',
#   'points': 94,
#   'price': 85.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Black Kite'},
#  {'ID': 308,
#   'country': 'US',
#   'designation': 'King Ridge Vineyard Hirsch Selection',
#   'points': 94,
#   'price': 70.0,
#   'province': 'California',
#   'region': 'Fort Ross-Seaview',
#   'variety': 'Pinot Noir',
#   'winery': 'Blue Farm'},
#  {'ID': 309,
#   'country': 'US',
#   'designation': 'Evenstad Reserve',
#   'points': 94,
#   'price': 70.0,
#   'province': 'Oregon',
#   'region': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine Serene'},
#  {'ID': 310,
#   'country': 'US',
#   'designation': 'Bacigalupi Vineyard',
#   'points': 94,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Gary Farrell'},
#  {'ID': 311,
#   'country': 'Italy',
#   'designation': 'Contrada Salvarenza Vecchie Vigne',
#   'points': 94,
#   'price': 38.0,
#   'province': 'Veneto',
#   'region': 'Soave Classico',
#   'variety': 'Garganega',
#   'winery': 'Gini'},
#  {'ID': 312,
#   'country': 'Italy',
#   'designation': 'La Froscà',
#   'points': 94,
#   'price': 29.0,
#   'province': 'Veneto',
#   'region': 'Soave Classico',
#   'variety': 'Garganega',
#   'winery': 'Gini'},
#  {'ID': 313,
#   'country': 'US',
#   'designation': 'Outer Limits',
#   'points': 94,
#   'price': 155.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Parallel'},
#  {'ID': 314,
#   'country': 'US',
#   'designation': 'Durant Vineyard Bishop Block',
#   'points': 94,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  {'ID': 315,
#   'country': 'US',
#   'designation': 'Godspeed',
#   'points': 94,
#   'price': 95.0,
#   'province': 'California',
#   'region': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Sbragia'},
#  {'ID': 316,
#   'country': 'US',
#   'designation': 'Tognetti Vineyard Brut',
#   'points': 94,
#   'price': 80.0,
#   'province': 'California',
#   'region': 'Carneros',
#   'variety': 'Sparkling Blend',
#   'winery': 'Schramsberg'},
#  {'ID': 317,
#   'country': 'US',
#   'designation': 'Ribbon Ridge Estate',
#   'points': 94,
#   'price': 49.0,
#   'province': 'Oregon',
#   'region': 'Ribbon Ridge',
#   'variety': 'Pinot Noir',
#   'winery': 'Trisaetum'},
#  {'ID': 318,
#   'country': 'France',
#   'designation': 'Château Montus',
#   'points': 94,
#   'price': 35.0,
#   'province': 'Southwest France',
#   'region': 'Madiran',
#   'variety': 'Tannat-Cabernet',
#   'winery': 'Vignobles Brumont'},
#  {'ID': 319,
#   'country': 'US',
#   'designation': 'Old Stones',
#   'points': 94,
#   'price': 50.0,
#   'province': 'Washington',
#   'region': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Waters'},
#  {'ID': 320,
#   'country': 'France',
#   'designation': 'La Bégude',
#   'points': 94,
#   'price': 44.0,
#   'province': 'Provence',
#   'region': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  {'ID': 321,
#   'country': 'Spain',
#   'designation': 'QP',
#   'points': 94,
#   'price': 68.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Bodega Classica'},
#  {'ID': 324,
#   'country': 'US',
#   'designation': 'Pellet Vineyard',
#   'points': 94,
#   'price': 95.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Pellet Estate'},
#  {'ID': 325,
#   'country': 'France',
#   'designation': 'La Bégude',
#   'points': 94,
#   'price': 44.0,
#   'province': 'Provence',
#   'region': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  {'ID': 326,
#   'country': 'Argentina',
#   'designation': 'Alta Barrancas Vineyards',
#   'points': 94,
#   'price': 50.0,
#   'province': 'Mendoza Province',
#   'region': 'Mendoza',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Pascual Toso'},
#  {'ID': 327,
#   'country': 'France',
#   'designation': 'Garrus',
#   'points': 94,
#   'price': 100.0,
#   'province': 'Provence',
#   'region': 'Côtes de Provence',
#   'variety': 'Rosé',
#   'winery': "Château d'Esclans"},
#  {'ID': 328,
#   'country': 'France',
#   'designation': 'Cuvée Marguerite Massaut',
#   'points': 94,
#   'price': 70.0,
#   'province': 'Southwest France',
#   'region': 'Cahors',
#   'variety': 'Malbec',
#   'winery': 'Château Lagrézette'},
# ...
#   'winery': 'Ferllen'},
#  {'ID': 1598,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 87,
#   'price': 140.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Tenuta di Sesta'},
#  {'ID': 1599,
#   'country': 'Italy',
#   'designation': 'Due Sorelle Riserva',
#   'points': 87,
#   'price': 60.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Tenuta La Fuga'},
#  {'ID': 1600,
#   'country': 'Italy',
#   'designation': 'Emilio Primo',
#   'points': 87,
#   'price': 25.0,
#   'province': 'Tuscany',
#   'region': 'Bolgheri',
#   'variety': 'Red Blend',
#   'winery': 'Terre del Marchesato'},
#  {'ID': 1602,
#   'country': 'Italy',
#   'designation': 'Ripe al Convento Riserva',
#   'points': 87,
#   'price': 138.0,
#   'province': 'Tuscany',
#   'region': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Castelgiocondo'},
#  {'ID': 1606,
#   'country': 'US',
#   'designation': 'Cutthroat Blend',
#   'points': 87,
#   'price': 35.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Red Blend',
#   'winery': 'Flying Trout'},
#  {'ID': 1607,
#   'country': 'US',
#   'designation': 'Mélange Blanc',
#   'points': 87,
#   'price': 23.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'White Blend',
#   'winery': 'Patterson'},
#  {'ID': 1608,
#   'country': 'France',
#   'designation': 'Château Courbian',
#   'points': 87,
#   'price': 19.0,
#   'province': 'Bordeaux',
#   'region': 'Médoc',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Producta Vignobles'},
#  {'ID': 1610,
#   'country': 'US',
#   'designation': 'Sofia Blanc de Blancs',
#   'points': 87,
#   'price': 19.0,
#   'province': 'California',
#   'region': 'Monterey County',
#   'variety': 'Sparkling Blend',
#   'winery': 'Francis Ford Coppola'},
#  {'ID': 1612,
#   'country': 'US',
#   'designation': 'Springline Super Tuscan-style',
#   'points': 87,
#   'price': 19.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'White Blend',
#   'winery': 'Genoa'},
#  {'ID': 1613,
#   'country': 'US',
#   'designation': 'Bacigalupi Vineyard',
#   'points': 87,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Graton Ridge'},
#  {'ID': 1614,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 87,
#   'price': 20.0,
#   'province': 'California',
#   'region': 'Anderson Valley',
#   'variety': 'Gewürztraminer',
#   'winery': 'Navarro'},
#  {'ID': 1615,
#   'country': 'US',
#   'designation': 'Sharp Sisters',
#   'points': 87,
#   'price': 26.0,
#   'province': 'Washington',
#   'region': 'Columbia Valley (WA)',
#   'variety': 'Red Blend',
#   'winery': 'Mercer'},
#  {'ID': 1617,
#   'country': 'US',
#   'designation': 'Estate Grown',
#   'points': 87,
#   'price': 60.0,
#   'province': 'Washington',
#   'region': 'Columbia Gorge (WA)',
#   'variety': 'Syrah',
#   'winery': 'Syncline'},
#  {'ID': 1618,
#   'country': 'US',
#   'designation': 'Boushey Vineyard',
#   'points': 87,
#   'price': 25.0,
#   'province': 'Washington',
#   'region': 'Yakima Valley',
#   'variety': 'Grenache Blanc',
#   'winery': 'Syncline'},
#  {'ID': 1620,
#   'country': 'France',
#   'designation': 'Brut Prestige',
#   'points': 91,
#   'price': 66.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Champagne Blend',
#   'winery': 'Charles Ellner'},
#  {'ID': 1622,
#   'country': 'France',
#   'designation': 'Brut Nature',
#   'points': 91,
#   'price': 75.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Champagne Blend',
#   'winery': 'Ayala'},
#  {'ID': 1623,
#   'country': 'Italy',
#   'designation': 'Riserva',
#   'points': 90,
#   'price': 25.0,
#   'province': 'Tuscany',
#   'region': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Fattoria La Ripa'},
#  {'ID': 1624,
#   'country': 'US',
#   'designation': 'Special Reserve',
#   'points': 90,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Herzog'},
#  {'ID': 1625,
#   'country': 'US',
#   'designation': 'Estate Grown Cave Fermented',
#   'points': 90,
#   'price': 95.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Merlot',
#   'winery': 'Jarvis'},
#  {'ID': 1626,
#   'country': 'US',
#   'designation': 'Sierra Madre Vineyard',
#   'points': 90,
#   'price': 48.0,
#   'province': 'California',
#   'region': 'Santa Barbara County',
#   'variety': 'Pinot Noir',
#   'winery': 'La Montagne'},
#  {'ID': 1627,
#   'country': 'US',
#   'designation': 'Lachini Family Estate',
#   'points': 90,
#   'price': 48.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Lachini'},
#  {'ID': 1628,
#   'country': 'US',
#   'designation': 'Serious',
#   'points': 90,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Lodi',
#   'variety': 'Zinfandel',
#   'winery': 'Macchia'},
#  {'ID': 1629,
#   'country': 'US',
#   'designation': 'Estate 25th Anniversary',
#   'points': 90,
#   'price': 28.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Chardonnay',
#   'winery': 'McIntyre Vineyards'},
#  {'ID': 1631,
#   'country': 'US',
#   'designation': 'Reed Vineyard',
#   'points': 90,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Mt. Harlan',
#   'variety': 'Pinot Noir',
#   'winery': 'Calera'},
#  {'ID': 1633,
#   'country': 'France',
#   'designation': 'Grande Réserve Brut',
#   'points': 90,
#   'price': 50.0,
#   'province': 'Champagne',
#   'region': 'Champagne',
#   'variety': 'Champagne Blend',
#   'winery': 'Charles Ellner'},
#  {'ID': 1634,
#   'country': 'France',
#   'designation': 'La Chêneraie',
#   'points': 90,
#   'price': 55.0,
#   'province': 'Bordeaux',
#   'region': 'Fronsac',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Jeandeman'},
#  {'ID': 1638,
#   'country': 'Italy',
#   'designation': 'Limne',
#   'points': 90,
#   'price': 19.0,
#   'province': 'Lombardy',
#   'region': 'Lugana',
#   'variety': 'Turbiana',
#   'winery': 'Tenuta Roveglia'},
#  {'ID': 1639,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 90,
#   'price': 50.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Triumph Cellars'},
#  {'ID': 1642,
#   'country': 'US',
#   'designation': 'Dark & Brooding',
#   'points': 90,
#   'price': 54.0,
#   'province': 'California',
#   'region': 'Sonoma County',
#   'variety': 'Red Blend',
#   'winery': 'Palmeri'},
#  {'ID': 1644,
#   'country': 'US',
#   'designation': 'Pendulum',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Monterey County',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Baker & Brain'},
#  {'ID': 1645,
#   'country': 'US',
#   'designation': 'Bald Mountain Vineyard',
#   'points': 90,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Ben Lomond Mountain',
#   'variety': 'Chardonnay',
#   'winery': 'Beauregard'},
#  {'ID': 1650,
#   'country': 'US',
#   'designation': 'The Augur Kick On Ranch Vineyard',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Santa Barbara County',
#   'variety': 'Riesling',
#   'winery': 'j.brix'},
#  {'ID': 1651,
#   'country': 'US',
#   'designation': '1149 Rosé of',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Paso Robles Willow Creek District',
#   'variety': 'Mourvèdre',
#   'winery': 'Jada Vineyard & Winery'},
#  {'ID': 1653,
#   'country': 'US',
#   'designation': 'Brut Rosé',
#   'points': 88,
#   'price': 30.0,
#   'province': 'California',
#   'region': 'Arroyo Grande Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Laetitia'},
#  {'ID': 1654,
#   'country': 'US',
#   'designation': 'Rayhill Vineyard',
#   'points': 88,
#   'price': 60.0,
#   'province': 'California',
#   'region': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Landmark'},
#  {'ID': 1656,
#   'country': 'Italy',
#   'designation': 'Quercegobbe',
#   'points': 88,
#   'price': 65.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Merlot',
#   'winery': 'Petra'},
#  {'ID': 1657,
#   'country': 'Italy',
#   'designation': 'Maurleo',
#   'points': 88,
#   'price': 19.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Pietro Beconcini'},
#  {'ID': 1658,
#   'country': 'Italy',
#   'designation': 'Lippo',
#   'points': 88,
#   'price': 28.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Pieve Santo Stefano'},
#  {'ID': 1661,
#   'country': 'US',
#   'designation': 'Dianthus',
#   'points': 88,
#   'price': 27.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Rosé',
#   'winery': 'Tablas Creek'},
#  {'ID': 1662,
#   'country': 'Italy',
#   'designation': 'Trasolo',
#   'points': 88,
#   'price': 120.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Merlot',
#   'winery': 'Tenuta Villa Trasqua'},
#  {'ID': 1664,
#   'country': 'France',
#   'designation': "Baron d'Ardeuil Vieilles Vignes",
#   'points': 88,
#   'price': 15.0,
#   'province': 'Southwest France',
#   'region': 'Buzet',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Vignerons de Buzet'},
#  {'ID': 1666,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 88,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Santa Cruz Mountains',
#   'variety': 'Chardonnay',
#   'winery': 'Wrights Station'},
#  {'ID': 1668,
#   'country': 'France',
#   'designation': 'Cuvée des Conti',
#   'points': 88,
#   'price': 16.0,
#   'province': 'Southwest France',
#   'region': 'Bergerac Sec',
#   'variety': 'Bordeaux-style White Blend',
#   'winery': 'Château Tour des Gendres'},
#  {'ID': 1669,
#   'country': 'France',
#   'designation': 'Château Bazin',
#   'points': 88,
#   'price': 45.0,
#   'province': 'Southwest France',
#   'region': 'Côtes du Marmandais',
#   'variety': 'Red Blend',
#   'winery': 'Cave du Marmandais'},
#  {'ID': 1670,
#   'country': 'Italy',
#   'designation': 'Serisè',
#   'points': 88,
#   'price': 22.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Ciliegiolo',
#   'winery': 'Cesani'},
#  {'ID': 1673,
#   'country': 'Italy',
#   'designation': 'Poggio ai Merli',
#   'points': 88,
#   'price': 110.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Merlot',
#   'winery': 'Castellare di Castellina'},
#  {'ID': 1674,
#   'country': 'Italy',
#   'designation': 'Non Confonditur',
#   'points': 88,
#   'price': 26.0,
#   'province': 'Tuscany',
#   'region': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Argiano'},
#  {'ID': 1675,
#   'country': 'US',
#   'designation': 'Hope',
#   'points': 88,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'California',
#   'variety': 'Red Blend',
#   'winery': 'Aver Family Vineyards'},
#  {'ID': 1677,
#   'country': 'US',
#   'designation': 'The Sheriff',
#   'points': 88,
#   'price': 36.0,
#   'province': 'California',
#   'region': 'Livermore Valley',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Vasco Urbano'},
#  {'ID': 1679,
#   'country': 'Spain',
#   'designation': 'Castillo de Albai Crianza',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Pagos del Rey'},
#  {'ID': 1682,
#   'country': 'US',
#   'designation': 'Alloro Vineyard',
#   'points': 88,
#   'price': 60.0,
#   'province': 'Oregon',
#   'region': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Torii Mor'},
#  {'ID': 1684,
#   'country': 'US',
#   'designation': 'Upstream',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Lodi',
#   'variety': 'Zinfandel',
#   'winery': 'Watts'},
#  {'ID': 1690,
#   'country': 'US',
#   'designation': 'York Creek Vineyard',
#   'points': 88,
#   'price': 37.0,
#   'province': 'California',
#   'region': 'Napa Valley',
#   'variety': 'Petite Sirah',
#   'winery': 'Elyse'},
#  {'ID': 1692,
#   'country': 'US',
#   'designation': 'Preston Vineyards',
#   'points': 88,
#   'price': 25.0,
#   'province': 'California',
#   'region': 'Dry Creek Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Horse & Plow'},
#  {'ID': 1693,
#   'country': 'US',
#   'designation': 'Le Cigare Blanc Beeswax Vineyard',
#   'points': 88,
#   'price': 26.0,
#   'province': 'California',
#   'region': 'Arroyo Seco',
#   'variety': 'Rhône-style White Blend',
#   'winery': 'Bonny Doon'},
#  {'ID': 1698,
#   'country': 'US',
#   'designation': 'Estate',
#   'points': 88,
#   'price': 10.0,
#   'province': 'California',
#   'region': 'Amador County',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Clos du Lac'},
#  {'ID': 1700,
#   'country': 'US',
#   'designation': 'Sexton Hill Vineyard',
#   'points': 88,
#   'price': 42.0,
#   'province': 'California',
#   'region': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Balletto'},
#  {'ID': 1704,
#   'country': 'Spain',
#   'designation': 'Maceración Carbónica',
#   'points': 88,
#   'price': 16.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Dominio de Berzal'},
#  {'ID': 1705,
#   'country': 'Spain',
#   'designation': "AV14 Clos d'Englora",
#   'points': 88,
#   'price': 30.0,
#   'province': 'Catalonia',
#   'region': 'Montsant',
#   'variety': 'Red Blend',
#   'winery': 'Cellers Baronia del Montsant'},
#  {'ID': 1706,
#   'country': 'Spain',
#   'designation': 'Inspiración Las Canteras',
#   'points': 88,
#   'price': 25.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Bodegas Valdemar'},
#  {'ID': 1707,
#   'country': 'Spain',
#   'designation': 'Crianza',
#   'points': 88,
#   'price': 15.0,
#   'province': 'Northern Spain',
#   'region': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Viña Herminia'},
#  {'ID': 1710,
#   'country': 'US',
#   'designation': 'DuPratt Vineyard Old Vine',
#   'points': 90,
#   'price': 24.0,
#   'province': 'California',
#   'region': 'Mendocino Ridge',
#   'variety': 'Zinfandel',
#   'winery': 'Steele'},
#  {'ID': 1713,
#   'country': 'France',
#   'designation': 'Maison du Villard',
#   'points': 90,
#   'price': 35.0,
#   'province': 'Burgundy',
#   'region': 'Pouilly-Fuissé',
#   'variety': 'Chardonnay',
#   'winery': 'Château de Lavernette'},
#  {'ID': 1714,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 90,
#   'price': 18.0,
#   'province': 'California',
#   'region': 'El Dorado',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Lava Cap'},
#  {'ID': 1716,
#   'country': 'US',
#   'designation': 'Estate Bottled',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Shenandoah Valley (CA)',
#   'variety': 'Zinfandel',
#   'winery': 'Easton'},
#  {'ID': 1717,
#   'country': 'US',
#   'designation': 'Reserve',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'Edna Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Edna Valley Vineyard'},
#  {'ID': 1719,
#   'country': 'US',
#   'designation': 'Erato De Portola Trail Vineyard',
#   'points': 90,
#   'price': 45.0,
#   'province': 'California',
#   'region': 'Temecula Valley',
#   'variety': 'Cabernet Franc',
#   'winery': 'Gershon Bachus'},
#  {'ID': 1720,
#   'country': 'US',
#   'designation': 'El Jabali Vineyard Brut Rosé',
#   'points': 90,
#   'price': 65.0,
#   'province': 'California',
#   'region': 'Sta. Rita Hills',
#   'variety': 'Sparkling Blend',
#   'winery': 'Alma Rosa'},
#  {'ID': 1721,
#   'country': 'US',
#   'designation': 'Collins Holystone Vineyard Old Vine',
#   'points': 90,
#   'price': 35.0,
#   'province': 'California',
#   'region': 'St. Helena',
#   'variety': 'Zinfandel',
#   'winery': 'Benessere'},
#  {'ID': 1722,
#   'country': 'US',
#   'designation': 'Makena',
#   'points': 90,
#   'price': 35.0,
#   'province': 'Oregon',
#   'region': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'BKB'},
#  {'ID': 1723,
#   'country': 'US',
#   'designation': 'Mortal Zin',
#   'points': 90,
#   'price': 38.0,
#   'province': 'California',
#   'region': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Graveyard'},
#  {'ID': 1724,
#   'country': 'US',
#   'designation': 'Aatto',
#   'points': 90,
#   'price': 40.0,
#   'province': 'California',
#   'region': 'Adelaida District',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'kukkula'},
#  {'ID': 1726,
#   'country': 'US',
#   'designation': 'The Villain',
#   'points': 90,
#   'price': 34.0,
#   'province': 'California',
#   'region': 'Santa Lucia Highlands',
#   'variety': 'Syrah',
#   'winery': 'Shane Wines'},
#  ...]

# %% [markdown]
# # 🤔
#
# This sort of, kind of, looks like a list of lists, but we have the header repeated a bunch of times.
#
# These are dictionaries.
#
# ## Dictionaries
#
# Together with lists, dictionaries are the other construct we use to structure data within our programs.
#
# They're used to organize data, but in a way that makes it easy to keep data consistent.
#
# Simplest dictionaries are sequences of `key`, `value` pairs. Just like with a physical dictionary, where we can use a word to look up its definition or translation, in `Python` dictionaries we use a `key` to fetch some extra piece of data (`value`) associated with it.
#
# Another way to think about dictionaries is that they create a separate space for us to create variables within variables.
#
# Let's take a look.

# %%
# TODO: create empty dictionary

me={}
# TODO: add items with keys


me["name"] = "Jia"
me["zipcode"] = "12219"
me["grade"] = "100"

display(me)

# TODO: create and initialize
you ={
  "name": "Vincenzo",
  "zipcode": "12345",
  "grade" : "80",
}


# TODO: read a value from a key
me["grade"] >you["grade"]

# TODO: useful for comparing things that should be alike and have similar properties

# TODO: can modify value associated with any given key

# TODO: or remove
# Out:
# {'name': 'Jia', 'zipcode': '12219', 'grade': '100'}
# False

# %% [markdown]
# ## Objects
#
# This is another name for dictionaries. People also use _hash map_, _hash table_ and _associative array_ to refer to objects/dictionaries. They all mean the same thing.
#
# One reason why people use some of these other terms is that the term _dictionary_ might imply, or be closely associated with, a simple `key` $\to$ `value` type of organization, like in physical dictionaries. But, `Python` dictionaries are more sophisticated because they allow a `key` to be associated with a more complex data type like a `list` or even a `dictionary`.
#
# So, yeah, nested dictionaries are a thing... so are lists of dictionaries and dictionaries with lists.

# %%
# TODO: add list values
me= {
  "name":"Jia",
  "grades":{100,90,98,99},
}

you = {
  "name" : "Lex",
  "grades" : {100,72,99,98},
}

people = {me, you}
# TODO: add average to dictionary

for p in people:
  p["average"]=sum(p

# TODO: first, create list of dicts

# TODO: process list and add average

# %% [markdown]
# ## Datasets
#
# We've now seen $2$ ways of storing datasets in text files. Some of the details between them are a little different, but they have a similar overall structure for organizing data in $2$ dimensions: rows and columns.
#
# <img src="./imgs/datasets00.jpg" width="700px">
#
# In `csv` files we have an outer list of rows that have inner lists of the column values, and in `json` files we have an outer list of rows that have inner objects with the column values.
#
# <img src="./imgs/datasets01.jpg" width="700px">
#
# But what we can do with one, we can do with the other.
#
# Let's repeat some of the processing we did with the wines from last week, but this time using `json` data (a list of objects).

# %% [markdown]
# ### Wines
#
# Let's find the most expensive wine on the dataset and the average price of wines from California.

# %%
# iterate over wines and find most expensive wine

# assume it's the first wine
expensive_wine = data[0]

# for every wine on the list, compare its price property 
#   to the price of the most expensive wine we have seen so far.
# if we see a more expensive wine, update the expensive_wine result variable

for w in data:
  if w["price"] > expensive_wine["price"]:
    expensive_wine = w

expensive_wine

# %%
# iterate over wines and calculate average price for California wines

# we need the sum of their prices and the number of wines from California
# we can first filter the wines from California, and then sum the prices, or do both at once

# the result variables
sum_ca_prices = 0
cnt_ca_wines = 0

for w in data:
  if w["province"] == "California":
    sum_ca_prices = sum_ca_prices + w["price"]
    cnt_ca_wines = cnt_ca_wines + 1

print(sum_ca_prices, cnt_ca_wines, sum_ca_prices / cnt_ca_wines)

# %% [markdown]
# ### Exercise
#
# Find the cheapest wine from the US and the cheapest wine not from the US.
#
# Just like we can check for equality using `==`, we can check for inequality using `!=`.
#
# So, wines not from the US are the ones that have `w["country"] != "US"`

# %%
# TODO: cheap wines

wine=open("data/wines.json")
wineData= json.load(wine)

#for wine in wineData:
  #if wine["country"] != "US":
    #print(wine)


# TODO: set up some variables to hold the result we want

spanishWine = []
frenchWine = []
amiWine = []

for wine in wineData:
  if wine["country"] == "Spain":
    spanishWine.append(wine)
print (spanishWine)
# TODO: iterate and use if statements to determine when/if we should update the results

# TODO: can do it using 2 separate loops or combine the logic into one loop
# Out:
# [{'ID': 1, 'country': 'Spain', 'designation': 'Carodorum Selección Especial Reserva', 'points': 96, 'price': 110.0, 'province': 'Northern Spain', 'region': 'Toro', 'variety': 'Tinta de Toro', 'winery': 'Bodega Carmen Rodríguez'}, {'ID': 5, 'country': 'Spain', 'designation': 'Numanthia', 'points': 95, 'price': 73.0, 'province': 'Northern Spain', 'region': 'Toro', 'variety': 'Tinta de Toro', 'winery': 'Numanthia'}, {'ID': 6, 'country': 'Spain', 'designation': 'San Román', 'points': 95, 'price': 65.0, 'province': 'Northern Spain', 'region': 'Toro', 'variety': 'Tinta de Toro', 'winery': 'Maurodos'}, {'ID': 7, 'country': 'Spain', 'designation': 'Carodorum Único Crianza', 'points': 95, 'price': 110.0, 'province': 'Northern Spain', 'region': 'Toro', 'variety': 'Tinta de Toro', 'winery': 'Bodega Carmen Rodríguez'}, {'ID': 17, 'country': 'Spain', 'designation': '6 Años Reserva Premium', 'points': 95, 'price': 80.0, 'province': 'Northern Spain', 'region': 'Ribera del Duero', 'variety': 'Tempranillo', 'winery': 'Valduero'}, {'ID': 21, 'country': 'Spain', 'designation': 'Prado Enea Gran Reserva', 'points': 95, 'price': 79.0, 'province': 'Northern Spain', 'region': 'Rioja', 'variety': 'Tempranillo Blend', 'winery': 'Muga'}, {'ID': 22, 'country': 'Spain', 'designation': 'Termanthia', 'points': 95, 'price': 220.0, 'province': 'Northern Spain', 'region': 'Toro', 'variety': 'Tinta de Toro', 'winery': 'Numanthia'}, {'ID': 40, 'country': 'Spain', 'designation': 'Amandi', 'points': 90, 'price': 17.0, 'province': 'Galicia', 'region': 'Ribeira Sacra', 'variety': 'Mencía', 'winery': 'Don Bernardino'}, {'ID': 41, 'country': 'Spain', 'designation': 'Alfonso Oloroso Seco', 'points': 90, 'price': 26.0, 'province': 'Andalucia', 'region': 'Jerez', 'variety': 'Palomino', 'winery': 'González Byass'}, {'ID': 128, 'country': 'Spain', 'designation': 'Arnegui Reserva', 'points': 90, 'price': 22.0, 'province': 'Northern Spain', 'region': 'Rioja', 'variety': 'Tempranillo', 'winery': 'Pagos del Rey'}, {'ID': 138, 'country': 'Spain', 'designation': 'Crianza', 'points': 90, 'price': 17.0, 'province': 'Northern Spain', 'region': 'Rioja', 'variety': 'Tempranillo', 'winery': 'Valdelacierva'}, {'ID': 152, 'country': 'Spain', 'designation': 'Brut Reserva', 'points': 89, 'price': 17.0, 'province': 'Catalonia', 'region': 'Cava', 'variety': 'Sparkling Blend', 'winery': 'Bohigas'}, {'ID': 158, 'country': 'Spain', 'designation': 'Viña Real Gran Reserva', 'points': 89, 'price': 44.0, 'province': 'Northern Spain', 'region': 'Rioja', 'variety': 'Tempranillo', 'winery': 'CVNE'}, {'ID': 162, 'country': 'Spain', 'designation': 'Gaudium', 'points': 89, 'price': 44.0, 'province': 'Northern Spain', 'region': 'Rioja', 'variety': 'Tempranillo Blend', 'winery': 'Marqués de Cáceres'}, {'ID': 175, 'country': 'Spain', 'designation': 'Gran Bajoz', 'points': 89, 'price': 30.0, 'province': 'Northern Spain', 'region': 'Toro', 'variety': 'Tinta de Toro', 'winery': 'Pagos del Rey'}, {'ID': 188, 'country': 'Spain', 'designation': 'Sobre Lías', 'points': 88, 'price': 25.0, 'province': 'Northern Spain', 'region': 'Valdeorras', 'variety': 'Godello', 'winery': 'Valdesil'}, {'ID': 189, 'country': 'Spain', 'designation': 'Negre', 'points': 87, 'price': 22.0, 'province': 'Catalonia', 'region': 'Montsant', 'variety': 'Red Blend', 'winery': 'Jaspi'}, {'ID': 209, 'country': 'Spain', 'designation': 'Yá Cuvée 23 Brut Rosé', 'points': 87, 'price': 18.0, 'province': 'Catalonia', 'region': 'Cava', 'variety': 'Sparkling Blend', 'winery': 'Sumarroca'}, {'ID': 259, 'country': 'Spain', 'designation': 'Prestigio', 'points': 88, 'price': 30.0, 'province': 'Northern Spain', 'region': 'Cigales', 'variety': 'Tempranillo', 'winery': 'Val de Los Frailes'}, {'ID': 260, 'country': 'Spain', 'designation': 'Crianza', 'points': 88, 'price': 17.0, 'province': 'Central Spain', 'region': 'La Mancha', 'variety': 'Tempranillo Blend', 'winery': 'Yuntero'}, {'ID': 321, 'country': 'Spain', 'designation': 'QP', 'points': 94, 'price': 68 ...

# %% [markdown]
# ## Dictionary in Dictionary
#
# Let's open up another file and take a look at its structure.

# %%
ansurfile = open("./data/ansur.json")
ansurdata = json.load(ansurfile)

ansurdata[0]

# %% [markdown]
# # 🤔
#
# The first $6$ or so properties look normal, but the last $4$ are actually dictionaries.
#
# These are nested dictionaries ! We can't do this in `csv` files.
#
# We can still get to the values, we just have to do some double indexing.
#
# In order to get foot length we first get the `foot` object, and then its `length` value.

# %%
# get foot length data for person at index 10

ansurdata[10]["foot"]["length"]

# %% [markdown]
# ### Filtering and Finding
#
# Finding specific people and filtering the dataset is still similar, the biggest change being how we index our objects to get the values we want to compare.

# %%
# Get person with largest foot

big_foot = ansurdata[0]

for p in ansurdata:
  if p["foot"]["length"] > big_foot["foot"]["length"]:
    big_foot = p

big_foot

# %% [markdown]
# ### Exercise
#
# Repeat and find person with longest ears.

# %%
# TODO: find person with longest ears

# %% [markdown]
# ## Functions
#
# Ways of defining set of sub-commands that we want to run multiple times, possibly on different data.
#
# We've seen the `sorted()` function. We give it a list and it applies some pre-defined commands on the list before it returns a version of the list with items arranged by value. We can give the function any list and will perform the routine that has pre-defined in order to return a sorted list.
#
# We can define our own functions with the `def` keyword, followed by our function name and a list of parameter variables:
#
# ```python
# def add_and_square(param0, param1):
#   # do some stuff
#   x = param0 + param1
#   y = x ** 2
#   return y
# ```

# %%
# TODO: figure out who weighs more, soldiers who are 21 and younger or over 21
# TODO: figure out who has longer ears

# TODO: first: go through people and separate into 2 lists using age > 20
# TODO: then:  extract list of values we're interested in and calculate average

# TODO: Ohhohhh: repetitive task ! Use function.
# TODO: there can be a function that calculates the average of the values in a list
# TODO: and also functions that given key value or valueS, extract those into a list
# TODO: like extract(people_list, "height") would return a list of all height values

# %% [markdown]
# ## Sorting (list of) objects
#
# We can sort lists of numbers or words like this:

# %%
x = [0,5,1,12,8,4,6]
y = ["elephant", "cow", "bull", "owl", "zebra", "chicken"]

print(sorted(x))
print(sorted(y))

# %% [markdown]
# Would be nice to do the same for lists of objects:

# %%
people = [
  { "name": "thiago", "grades": [89, 87, 94], "id": 1543 },
  { "name": "lex", "grades": [98, 78, 92], "id": 1311 },
]

print(sorted(people))

# %% [markdown]
# But this is ambiguous: sort how ? By what parameter ?
#
# Maybe once by name, then later by grade, or id ...
#
# We can sort lists of arbitrary "things" as long as we tell `Python` what to look at when comparing items.
#
# We do this by defining a function that extracts the item we want `Python` to use when sorting.

# %%
# define a function that will extract the "thing" we want to compare (foot length for now)

# given a person, return their foot length
def get_foot_length(P):
  return P["foot"]["length"]

# now we can pass this to the sort() function to use as the sorting "key"
display(sorted(ansurdata, key=get_foot_length))

# %% [markdown]
# We can reverse the order of the sort, and get the list from largest value to smallest value:

# %%
display(sorted(ansurdata, key=get_foot_length, reverse=True))

# %% [markdown]
# We can also use a `key` on `min()` and `max()` functions, to get the object with the largest or smallest values for that key.

# %%
display(min(ansurdata, key=get_foot_length))
display(max(ansurdata, key=get_foot_length))

# %% [markdown]
# ## Questions
#
# - How many people in dataset ?
# - How tall are the tallest and shortest persons ?
# - What are the largest and smallest values for weight ?
# - How long is the longest hand ? Who has it ?
# - Do older people weigh more ?
# - Are older people taller ?
# - Do taller people have bigger heads ?
